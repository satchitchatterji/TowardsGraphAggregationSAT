# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt

import clingo
from IPython.display import clear_output

# %%
# Some machinery to (dynamically) print things in the notebook
log_str = ""
def reset_log():
    global log_str
    log_str = ""
def log(msg):
    global log_str
    print(msg, flush=True)
    log_str += f"{msg}\n"
def print_log():
    global log_str
    print(log_str, end='', flush=True)

def display_solution(model):
    print(model)


def find_and_output_solution(
    asp_program,
    timeout=10,
    num_threads=1,
):
    """
    Calls the ASP solver to find answer sets,
    and translates these to solutions,
    which are printed in human-readable format.
    """

    reset_log()
    #log("..Grounding..")
    
    control = clingo.Control([f"--parallel-mode={num_threads}"])
    control.add("base", [], asp_program)
    control.ground([("base", [])])

    control.configuration.solve.models = 0
    control.configuration.solve.opt_mode = "optN"
    
    models = []

    def interpret_model(model):
        #clear_output(wait=True)
        #print_log()
        #reset_log()
        #print(display_solution(model))
        save_mod = str(model).replace(' ', ' ')
        models.append(save_mod)


    if timeout > 0:
        #log(f"..Solving with timeout {timeout}s..")
        with control.solve(
            async_=True,
            on_model=lambda model: interpret_model(model),
        ) as handle:
            finished = handle.wait(timeout)
            if not finished:
                log("..Stopped after timeout..")
            else:
                #log("..Stopped..")
                time = control.statistics['summary']['times']['total']
                #log(f"..Total solving time: {time:.2f} seconds..")
    else:
        #log("..Solving..")
        control.solve(
            on_model=lambda model: interpret_model(model),
        )
        #log("..Stopped..")
        time = control.statistics['summary']['times']['total']
        #log(f"..Total solving time: {time:.2f} seconds..")

    return models

# %%
with open('get_graphs.lp', 'r') as file:
    get_graphs = file.read()

with open('enum_graphs.lp', 'r') as file:
    enum_graphs = file.read()

with open('find_rule.lp', 'r') as file:
    find_rule = file.read()
#print(get_graphs)

# %%
n_nodes=3
consts = f"#const num_nodes={n_nodes}.\n"
prog = consts+get_graphs
#print(prog)
edge_out = find_and_output_solution(prog, timeout=60, num_threads=4)
print(edge_out)
print("total graphs:", len(edge_out))
# Out:
# ['edge(1,1) edge(2,1) edge(2,2) edge(3,1) edge(3,2) edge(3,3)', 'edge(1,1) edge(2,1) edge(2,2) edge(2,3) edge(3,1) edge(3,3)', 'edge(1,1) edge(2,1) edge(2,2) edge(2,3) edge(3,1) edge(3,2) edge(3,3)', 'edge(1,1) edge(1,3) edge(2,1) edge(2,2) edge(2,3) edge(3,3)', 'edge(1,1) edge(1,3) edge(2,1) edge(2,2) edge(2,3) edge(3,1) edge(3,3)', 'edge(1,1) edge(1,2) edge(2,2) edge(3,1) edge(3,2) edge(3,3)', 'edge(1,1) edge(1,2) edge(2,1) edge(2,2) edge(3,1) edge(3,2) edge(3,3)', 'edge(1,1) edge(1,2) edge(1,3) edge(2,2) edge(2,3) edge(3,3)', 'edge(1,1) edge(1,2) edge(1,3) edge(2,1) edge(2,2) edge(2,3) edge(3,3)', 'edge(1,1) edge(1,2) edge(1,3) edge(2,2) edge(3,2) edge(3,3)', 'edge(1,1) edge(1,2) edge(1,3) edge(2,2) edge(3,1) edge(3,2) edge(3,3)', 'edge(1,1) edge(1,2) edge(1,3) edge(2,1) edge(2,2) edge(2,3) edge(3,1) edge(3,2) edge(3,3)', 'edge(1,1) edge(1,2) edge(1,3) edge(2,2) edge(2,3) edge(3,2) edge(3,3)']
# total graphs: 13

# %%
def out_to_asp(out):
    return out.replace(' ', '. \n') + '.\n'

graph_out = []
for i, out in enumerate(edge_out):
    prog = f"""#const graph_num={i+1}.\n"""
    edges = out_to_asp(out)
    prog += edges
    prog += enum_graphs
    #print(prog)
    num_out = find_and_output_solution(prog)[0]
    reset_log()
    graph_out.append(num_out)

graph_asp = ""
for out in graph_out:
    graph_asp += out_to_asp(out)

print(graph_asp)
# Out:
# graph(1,edge(1,1)).
# graph(1,edge(2,1)).
# graph(1,edge(2,2)).
# graph(1,edge(3,1)).
# graph(1,edge(3,2)).
# graph(1,edge(3,3)).
# graph(2,edge(1,1)).
# graph(2,edge(2,1)).
# graph(2,edge(2,2)).
# graph(2,edge(2,3)).
# graph(2,edge(3,1)).
# graph(2,edge(3,3)).
# graph(3,edge(1,1)).
# graph(3,edge(2,1)).
# graph(3,edge(2,2)).
# graph(3,edge(2,3)).
# graph(3,edge(3,1)).
# graph(3,edge(3,2)).
# graph(3,edge(3,3)).
# graph(4,edge(1,1)).
# graph(4,edge(1,3)).
# graph(4,edge(2,1)).
# graph(4,edge(2,2)).
# graph(4,edge(2,3)).
# graph(4,edge(3,3)).
# graph(5,edge(1,1)).
# graph(5,edge(1,3)).
# graph(5,edge(2,1)).
# graph(5,edge(2,2)).
# graph(5,edge(2,3)).
# graph(5,edge(3,1)).
# graph(5,edge(3,3)).
# graph(6,edge(1,1)).
# graph(6,edge(1,2)).
# graph(6,edge(1,3)).
# graph(6,edge(2,2)).
# graph(6,edge(2,3)).
# graph(6,edge(3,3)).
# graph(7,edge(1,1)).
# graph(7,edge(1,2)).
# graph(7,edge(1,3)).
# graph(7,edge(2,1)).
# graph(7,edge(2,2)).
# graph(7,edge(2,3)).
# graph(7,edge(3,3)).
# graph(8,edge(1,1)).
# graph(8,edge(1,2)).
# graph(8,edge(1,3)).
# graph(8,edge(2,2)).
# graph(8,edge(3,2)).
# graph(8,edge(3,3)).
# graph(9,edge(1,1)).
# graph(9,edge(1,2)).
# graph(9,edge(1,3)).
# graph(9,edge(2,2)).
# graph(9,edge(2,3)).
# graph(9,edge(3,2)).
# graph(9,edge(3,3)).
# graph(10,edge(1,1)).
# graph(10,edge(1,2)).
# graph(10,edge(2,2)).
# graph(10,edge(3,1)).
# graph(10,edge(3,2)).
# graph(10,edge(3,3)).
# graph(11,edge(1,1)).
# graph(11,edge(1,2)).
# graph(11,edge(1,3)).
# graph(11,edge(2,2)).
# graph(11,edge(3,1)).
# graph(11,edge(3,2)).
# graph(11,edge(3,3)).
# graph(12,edge(1,1)).
# graph(12,edge(1,2)).
# graph(12,edge(2,1)).
# graph(12,edge(2,2)).
# graph(12,edge(3,1)).
# graph(12,edge(3,2)).
# graph(12,edge(3,3)).
# graph(13,edge(1,1)).
# graph(13,edge(1,2)).
# graph(13,edge(1,3)).
# graph(13,edge(2,1)).
# graph(13,edge(2,2)).
# graph(13,edge(2,3)).
# graph(13,edge(3,1)).
# graph(13,edge(3,2)).
# graph(13,edge(3,3)).

# %%
from itertools import permutations
def generate_profiles(n_agents=3,n_graphs=13):
    #n_graphs=13
    
    perms = list(permutations(range(1,n_graphs+1),n_agents))
    for i in range(1,n_graphs+1):
        perms += list([i] * n_agents)
    
    return perms

all_perms = generate_profiles()
print(all_perms)
# Out:
# [(1, 2, 3), (1, 2, 4), (1, 2, 5), (1, 2, 6), (1, 2, 7), (1, 2, 8), (1, 2, 9), (1, 2, 10), (1, 2, 11), (1, 2, 12), (1, 2, 13), (1, 3, 2), (1, 3, 4), (1, 3, 5), (1, 3, 6), (1, 3, 7), (1, 3, 8), (1, 3, 9), (1, 3, 10), (1, 3, 11), (1, 3, 12), (1, 3, 13), (1, 4, 2), (1, 4, 3), (1, 4, 5), (1, 4, 6), (1, 4, 7), (1, 4, 8), (1, 4, 9), (1, 4, 10), (1, 4, 11), (1, 4, 12), (1, 4, 13), (1, 5, 2), (1, 5, 3), (1, 5, 4), (1, 5, 6), (1, 5, 7), (1, 5, 8), (1, 5, 9), (1, 5, 10), (1, 5, 11), (1, 5, 12), (1, 5, 13), (1, 6, 2), (1, 6, 3), (1, 6, 4), (1, 6, 5), (1, 6, 7), (1, 6, 8), (1, 6, 9), (1, 6, 10), (1, 6, 11), (1, 6, 12), (1, 6, 13), (1, 7, 2), (1, 7, 3), (1, 7, 4), (1, 7, 5), (1, 7, 6), (1, 7, 8), (1, 7, 9), (1, 7, 10), (1, 7, 11), (1, 7, 12), (1, 7, 13), (1, 8, 2), (1, 8, 3), (1, 8, 4), (1, 8, 5), (1, 8, 6), (1, 8, 7), (1, 8, 9), (1, 8, 10), (1, 8, 11), (1, 8, 12), (1, 8, 13), (1, 9, 2), (1, 9, 3), (1, 9, 4), (1, 9, 5), (1, 9, 6), (1, 9, 7), (1, 9, 8), (1, 9, 10), (1, 9, 11), (1, 9, 12), (1, 9, 13), (1, 10, 2), (1, 10, 3), (1, 10, 4), (1, 10, 5), (1, 10, 6), (1, 10, 7), (1, 10, 8), (1, 10, 9), (1, 10, 11), (1, 10, 12), (1, 10, 13), (1, 11, 2), (1, 11, 3), (1, 11, 4), (1, 11, 5), (1, 11, 6), (1, 11, 7), (1, 11, 8), (1, 11, 9), (1, 11, 10), (1, 11, 12), (1, 11, 13), (1, 12, 2), (1, 12, 3), (1, 12, 4), (1, 12, 5), (1, 12, 6), (1, 12, 7), (1, 12, 8), (1, 12, 9), (1, 12, 10), (1, 12, 11), (1, 12, 13), (1, 13, 2), (1, 13, 3), (1, 13, 4), (1, 13, 5), (1, 13, 6), (1, 13, 7), (1, 13, 8), (1, 13, 9), (1, 13, 10), (1, 13, 11), (1, 13, 12), (2, 1, 3), (2, 1, 4), (2, 1, 5), (2, 1, 6), (2, 1, 7), (2, 1, 8), (2, 1, 9), (2, 1, 10), (2, 1, 11), (2, 1, 12), (2, 1, 13), (2, 3, 1), (2, 3, 4), (2, 3, 5), (2, 3, 6), (2, 3, 7), (2, 3, 8), (2, 3, 9), (2, 3, 10), (2, 3, 11), (2, 3, 12), (2, 3, 13), (2, 4, 1), (2, 4, 3), (2, 4, 5), (2, 4, 6), (2, 4, 7), (2, 4, 8), (2, 4, 9), (2, 4, 10), (2, 4, 11), (2, 4, 12), (2, 4, 13), (2, 5, 1), (2, 5, 3), (2, 5, 4), (2, 5, 6), (2, 5, 7), (2, 5, 8), (2, 5, 9), (2, 5, 10), (2, 5, 11), (2, 5, 12), (2, 5, 13), (2, 6, 1), (2, 6, 3), (2, 6, 4), (2, 6, 5), (2, 6, 7), (2, 6, 8), (2, 6, 9), (2, 6, 10), (2, 6, 11), (2, 6, 12), (2, 6, 13), (2, 7, 1), (2, 7, 3), (2, 7, 4), (2, 7, 5), (2, 7, 6), (2, 7, 8), (2, 7, 9), (2, 7, 10), (2, 7, 11), (2, 7, 12), (2, 7, 13), (2, 8, 1), (2, 8, 3), (2, 8, 4), (2, 8, 5), (2, 8, 6), (2, 8, 7), (2, 8, 9), (2, 8, 10), (2, 8, 11), (2, 8, 12), (2, 8, 13), (2, 9, 1), (2, 9, 3), (2, 9, 4), (2, 9, 5), (2, 9, 6), (2, 9, 7), (2, 9, 8), (2, 9, 10), (2, 9, 11), (2, 9, 12), (2, 9, 13), (2, 10, 1), (2, 10, 3), (2, 10, 4), (2, 10, 5), (2, 10, 6), (2, 10, 7), (2, 10, 8), (2, 10, 9), (2, 10, 11), (2, 10, 12), (2, 10, 13), (2, 11, 1), (2, 11, 3), (2, 11, 4), (2, 11, 5), (2, 11, 6), (2, 11, 7), (2, 11, 8), (2, 11, 9), (2, 11, 10), (2, 11, 12), (2, 11, 13), (2, 12, 1), (2, 12, 3), (2, 12, 4), (2, 12, 5), (2, 12, 6), (2, 12, 7), (2, 12, 8), (2, 12, 9), (2, 12, 10), (2, 12, 11), (2, 12, 13), (2, 13, 1), (2, 13, 3), (2, 13, 4), (2, 13, 5), (2, 13, 6), (2, 13, 7), (2, 13, 8), (2, 13, 9), (2, 13, 10), (2, 13, 11), (2, 13, 12), (3, 1, 2), (3, 1, 4), (3, 1, 5), (3, 1, 6), (3, 1, 7), (3, 1, 8), (3, 1, 9), (3, 1, 10), (3, 1, 11), (3, 1, 12), (3, 1, 13), (3, 2, 1), (3, 2, 4), (3, 2, 5), (3, 2, 6), (3, 2, 7), (3, 2, 8), (3, 2, 9), (3, 2, 10), (3, 2, 11), (3, 2, 12), (3, 2, 13), (3, 4, 1), (3, 4, 2), (3, 4, 5), (3, 4, 6), (3, 4, 7), (3, 4, 8), (3, 4, 9), (3, 4, 10), (3, 4, 11), (3, 4, 12), (3, 4, 13), (3, 5, 1), (3, 5, 2), (3, 5, 4), (3, 5, 6), (3, 5, 7), (3, 5, 8), (3, 5, 9), (3, 5, 10), (3, 5, 11), (3, 5, 12), (3, 5, 13), (3, 6, 1), (3, 6, 2), (3, 6, 4), (3, 6, 5), (3, 6, 7), (3, 6, 8), (3, 6, 9), (3, 6, 10), (3, 6, 11), (3, 6, 12), (3, 6, 13), (3, 7, 1), (3, 7, 2), (3, 7, 4), (3, 7, 5), (3, 7, 6), (3, 7, 8), (3, 7, 9), (3, 7, 10), (3, 7, 11), (3, 7, 12), (3, 7, 13), (3, 8, 1), (3, 8, 2), (3, 8, 4), (3, 8, 5), (3, 8, 6), (3, 8, 7), (3, 8, 9), (3, 8, 10), (3, 8, 11), (3, 8, 12), (3, 8, 13), (3, 9, 1), (3, 9, 2), (3, 9, 4), (3, 9, 5),  ...

# %%
import itertools
def generate_profiles(n_agents=3, n_graphs=13):
    g_range = list((range(1,n_graphs+1)))
    perms = [p for p in itertools.product(g_range, repeat=3)]
    #print(g_range)
    #print(perms)
    
    prog = f"""#const num_agents={n_agents}. #const num_graphs={n_graphs}. #const num_profiles={len(perms)}.\n""" + consts
    for i, p in enumerate(perms):
        if len(p) != n_agents:
            continue

        profile = i + 1
        for j, g in enumerate(p):
            agent = j + 1
            clause = f"profile({profile}, choose({agent},{g})).\n"

            prog += clause

    return prog

prof_asp = generate_profiles()

print(prof_asp)
# Out:
# #const num_agents=3. #const num_graphs=13. #const num_profiles=2197.
# #const num_nodes=3.
# profile(1, choose(1,1)).
# profile(1, choose(2,1)).
# profile(1, choose(3,1)).
# profile(2, choose(1,1)).
# profile(2, choose(2,1)).
# profile(2, choose(3,2)).
# profile(3, choose(1,1)).
# profile(3, choose(2,1)).
# profile(3, choose(3,3)).
# profile(4, choose(1,1)).
# profile(4, choose(2,1)).
# profile(4, choose(3,4)).
# profile(5, choose(1,1)).
# profile(5, choose(2,1)).
# profile(5, choose(3,5)).
# profile(6, choose(1,1)).
# profile(6, choose(2,1)).
# profile(6, choose(3,6)).
# profile(7, choose(1,1)).
# profile(7, choose(2,1)).
# profile(7, choose(3,7)).
# profile(8, choose(1,1)).
# profile(8, choose(2,1)).
# profile(8, choose(3,8)).
# profile(9, choose(1,1)).
# profile(9, choose(2,1)).
# profile(9, choose(3,9)).
# profile(10, choose(1,1)).
# profile(10, choose(2,1)).
# profile(10, choose(3,10)).
# profile(11, choose(1,1)).
# profile(11, choose(2,1)).
# profile(11, choose(3,11)).
# profile(12, choose(1,1)).
# profile(12, choose(2,1)).
# profile(12, choose(3,12)).
# profile(13, choose(1,1)).
# profile(13, choose(2,1)).
# profile(13, choose(3,13)).
# profile(14, choose(1,1)).
# profile(14, choose(2,2)).
# profile(14, choose(3,1)).
# profile(15, choose(1,1)).
# profile(15, choose(2,2)).
# profile(15, choose(3,2)).
# profile(16, choose(1,1)).
# profile(16, choose(2,2)).
# profile(16, choose(3,3)).
# profile(17, choose(1,1)).
# profile(17, choose(2,2)).
# profile(17, choose(3,4)).
# profile(18, choose(1,1)).
# profile(18, choose(2,2)).
# profile(18, choose(3,5)).
# profile(19, choose(1,1)).
# profile(19, choose(2,2)).
# profile(19, choose(3,6)).
# profile(20, choose(1,1)).
# profile(20, choose(2,2)).
# profile(20, choose(3,7)).
# profile(21, choose(1,1)).
# profile(21, choose(2,2)).
# profile(21, choose(3,8)).
# profile(22, choose(1,1)).
# profile(22, choose(2,2)).
# profile(22, choose(3,9)).
# profile(23, choose(1,1)).
# profile(23, choose(2,2)).
# profile(23, choose(3,10)).
# profile(24, choose(1,1)).
# profile(24, choose(2,2)).
# profile(24, choose(3,11)).
# profile(25, choose(1,1)).
# profile(25, choose(2,2)).
# profile(25, choose(3,12)).
# profile(26, choose(1,1)).
# profile(26, choose(2,2)).
# profile(26, choose(3,13)).
# profile(27, choose(1,1)).
# profile(27, choose(2,3)).
# profile(27, choose(3,1)).
# profile(28, choose(1,1)).
# profile(28, choose(2,3)).
# profile(28, choose(3,2)).
# profile(29, choose(1,1)).
# profile(29, choose(2,3)).
# profile(29, choose(3,3)).
# profile(30, choose(1,1)).
# profile(30, choose(2,3)).
# profile(30, choose(3,4)).
# profile(31, choose(1,1)).
# profile(31, choose(2,3)).
# profile(31, choose(3,5)).
# profile(32, choose(1,1)).
# profile(32, choose(2,3)).
# profile(32, choose(3,6)).
# profile(33, choose(1,1)).
# profile(33, choose(2,3)).
# profile(33, choose(3,7)).
# profile(34, choose(1,1)).
# profile(34, choose(2,3)).
# profile(34, choose(3,8)).
# profile(35, choose(1,1)).
# profile(35, choose(2,3)).
# profile(35, choose(3,9)).
# profile(36, choose(1,1)).
# profile(36, choose(2,3)).
# profile(36, choose(3,10)).
# profile(37, choose(1,1)).
# profile(37, choose(2,3)).
# profile(37, choose(3,11)).
# profile(38, choose(1,1)).
# profile(38, choose(2,3)).
# profile(38, choose(3,12)).
# profile(39, choose(1,1)).
# profile(39, choose(2,3)).
# profile(39, choose(3,13)).
# profile(40, choose(1,1)).
# profile(40, choose(2,4)).
# profile(40, choose(3,1)).
# profile(41, choose(1,1)).
# profile(41, choose(2,4)).
# profile(41, choose(3,2)).
# profile(42, choose(1,1)).
# profile(42, choose(2,4)).
# profile(42, choose(3,3)).
# profile(43, choose(1,1)).
# profile(43, choose(2,4)).
# profile(43, choose(3,4)).
# profile(44, choose(1,1)).
# profile(44, choose(2,4)).
# profile(44, choose(3,5)).
# profile(45, choose(1,1)).
# profile(45, choose(2,4)).
# profile(45, choose(3,6)).
# profile(46, choose(1,1)).
# profile(46, choose(2,4)).
# profile(46, choose(3,7)).
# profile(47, choose(1,1)).
# profile(47, choose(2,4)).
# profile(47, choose(3,8)).
# profile(48, choose(1,1)).
# profile(48, choose(2,4)).
# profile(48, choose(3,9)).
# profile(49, choose(1,1)).
# profile(49, choose(2,4)).
# profile(49, choose(3,10)).
# profile(50, choose(1,1)).
# profile(50, choose(2,4)).
# profile(50, choose(3,11)).
# profile(51, choose(1,1)).
# profile(51, choose(2,4)).
# profile(51, choose(3,12)).
# profile(52, choose(1,1)).
# profile(52, choose(2,4)).
# profile(52, choose(3,13)).
# profile(53, choose(1,1)).
# profile(53, choose(2,5)).
# profile(53, choose(3,1)).
# profile(54, choose(1,1)).
# profile(54, choose(2,5)).
# profile(54, choose(3,2)).
# profile(55, choose(1,1)).
# profile(55, choose(2,5)).
# profile(55, choose(3,3)).
# profile(56, choose(1,1)).
# profile(56, choose(2,5)).
# profile(56, choose(3,4)).
# profile(57, choose(1,1)).
# profile(57, choose(2,5)).
# profile(57, choose(3,5)).
# profile(58, choose(1,1)).
# profile(58, choose(2,5)).
# profile(58, choose(3,6)).
# profile(59, choose(1,1)).
# profile(59, choose(2,5)).
# profile(59, choose(3,7)).
# profile(60, choose(1,1)).
# profile(60, choose(2,5)).
# profile(60, choose(3,8)).
# profile(61, choose(1,1)).
# profile(61, choose(2,5)).
# profile(61, choose(3,9)).
# profile(62, choose(1,1)).
# profile(62, choose(2,5)).
# profile(62, choose(3,10)).
# profile(63, choose(1,1)).
# profile(63, choose(2,5)).
# profile(63, choose(3,11)).
# profile(64, choose(1,1)).
# profile(64, choose(2,5)).
# profile(64, choose(3,12)).
# profile(65, choose(1,1)).
# profile(65, choose(2,5)).
# profile(65, choose(3,13)).
# profile(66, choose(1,1)).
# profile(66, choose(2,6)).
# profile(66, choose(3,1)).
# profile(67, choose(1,1)).
# profile(67, choose(2,6)).
# profile(67, choose(3,2)).
# profile(68, choose(1,1)).
# profile(68, choose(2,6)).
# profile(68, choose(3,3)).
# profile(69, choose(1,1)).
# profile(69, choose(2,6)).
# profile(69, choose(3,4)).
# profile(70, choose(1,1)).
# profile(70, choose(2,6)).
# profile(70, choose(3,5)).
# profile(71, choose(1,1)).
# profile(71, choose(2,6)).
# profile(71, choose(3,6)).
# profile(72, choose(1,1)).
# profile(72, choose(2,6)).
# profile(72, choose(3,7)).
# profile(73, choose(1,1)).
# profile(73, choose(2,6)).
# profile(73, choose(3,8)).
# profile(74, choose(1,1)).
# profile(74, choose(2,6)).
# profile(74, choose(3,9)).
# profile(75, choose(1,1)).
# profile(75, choose(2,6)).
# profile(75, choose(3,10)).
# profile(76, choose(1,1)).
# profile(76, choose(2,6)).
# profile(76, choose(3,11)).
# profile(77, choose(1,1)).
# profile(77, choose(2,6)).
# profile(77, choose(3,12)).
# profile(78, choose(1,1)).
# profile(78, choose(2,6)).
# profile(78, choose(3,13)).
# profile(79, choose(1,1)).
# profile(79, choose(2,7)).
# profile(79, choose(3,1)).
# profile(80, choose(1,1)).
# profile(80, choose(2,7)).
# profile(80, choose(3,2)).
# profile(81, choose(1,1)).
# profile(81, choose(2,7)).
# profile(81, choose(3,3)).
# profile(82, choose(1,1)).
# profile(82, choose(2,7)).
# profile(82, choose(3,4)).
# profile(83, choose(1,1)).
# profile(83, choose(2,7)).
# profile(83, choose(3,5)).
# profile(84, choose(1,1)).
# profile(84, choose(2,7)).
# profile(84, choose(3,6)).
# profile(85, choose(1,1)).
# profile(85, choose(2,7)).
# profile(85, choose(3,7)).
# profile(86, choose(1,1)).
# profile(86, choose(2,7)).
# profile(86, choose(3,8)).
# profile(87, choose(1,1)).
# profile(87, choose(2,7)).
# profile(87, choose(3,9)).
# profile(88, choose(1,1)).
# profile(88, choose(2,7)).
# profile(88, choose(3,10)).
# profile(89, choose(1,1)).
# profile(89, choose(2,7)).
# profile(89, choose(3,11)).
# profile(90, choose(1,1)).
# profile(90, choose(2,7)).
# profile(90, choose(3,12)).
# profile(91, choose(1,1)).
# profile(91, choose(2,7)).
# profile(91, choose(3,13)).
# profile(92, choose(1,1)).
# profile(92, choose(2,8)).
# profile(92, choose(3,1)).
# profile(93, choose(1,1)).
# profile(93, choose(2,8)).
# profile(93, choose(3,2)).
# profile(94, choose(1,1)).
# profile(94, choose(2,8)).
# profile(94, choose(3,3)).
# profile(95, choose(1,1)).
# profile(95, choose(2,8)).
# profile(95, choose(3,4)).
# profile(96, choose(1,1)).
# profile(96, choose(2,8)).
# profile(96, choose(3,5)).
# profile(97, choose(1,1)).
# profile(97, choose(2,8)).
# profile(97, choose(3,6)).
# profile(98, choose(1,1)).
# profile(98, choose(2,8)).
# profile(98, choose(3,7)).
# profile(99, choose(1,1)).
# profile(99, choose(2,8)).
# profile(99, choose(3,8)).
# profile(100, choose(1,1)).
# profile(100, choose(2,8)).
# profile(100, choose(3,9)).
# profile(101, choose(1,1)).
# profile(101, choose(2,8)).
# profile(101, choose(3,10)).
# profile(102, choose(1,1)).
# profile(102, choose(2,8)).
# profile(102, choose(3,11)).
# profile(103, choose(1,1)).
# profile(103, choose(2,8)).
# profile(103, choose(3,12)).
# profile(104, choose(1,1)).
# profile(104, choose(2,8)).
# profile(104, choose(3,13)).
# profile(105, choose(1,1)).
# profile(105, choose(2,9)).
# profile(105, choose(3,1)).
# profile(106, choose(1,1)).
# profile(106, choose(2,9)).
# profile(106, choose(3,2)).
# profile(107, choose(1,1)).
# profile(107, choose(2,9)).
# profile(107, choose(3,3)).
# profile(108, choose(1,1)).
# profile(108, choose(2,9)).
# profile(108, choose(3,4)).
# profile(109, choose(1,1)).
# profile(109, choose(2,9)).
# profile(109, choose(3,5)).
# profile(110, choose(1,1)).
# profile(110, choose(2,9)).
# profile(110, choose(3,6)).
# profile(111, choose(1,1)).
# profile(111, choose(2,9)).
# profile(111, choose(3,7)).
# profile(112, choose(1,1)).
# profile(112, choose(2,9)).
# profile(112, choose(3,8)).
# profile(113, choose(1,1)).
# profile(113, choose(2,9)).
# profile(113, choose(3,9)).
# profile(114, choose(1,1)).
# profile(114, choose(2,9)).
# profile(114, choose(3,10)).
# profile(115, choose(1,1)).
# profile(115, choose(2,9)).
# profile(115, choose(3,11)).
# profile(116, choose(1,1)).
# profile(116, choose(2,9)).
# profile(116, choose(3,12)).
# profile(117, choose(1,1)).
# profile(117, choose(2,9)).
# profile(117, choose(3,13)).
# profile(118, choose(1,1)).
# profile(118, choose(2,10)).
# profile(118, choose(3,1)).
# profile(119, choose(1,1)).
# profile(119, choose(2,10)).
# profile(119, choose(3,2)).
# profile(120, choose(1,1)).
# profile(120, choose(2,10)).
# profile(120, choose(3,3)).
# profile(121, choose(1,1)).
# profile(121, choose(2,10)).
# profile(121, choose(3,4)).
# profile(122, choose(1,1)).
# profile(122, choose(2,10)).
# profile(122, choose(3,5)).
# profile(123, choose(1,1)).
# profile(123, choose(2,10)).
# profile(123, choose(3,6)).
# profile(124, choose(1,1)).
# profile(124, choose(2,10)).
# profile(124, choose(3,7)).
# profile(125, choose(1,1)).
# profile(125, choose(2,10)).
# profile(125, choose(3,8)).
# profile(126, choose(1,1)).
# profile(126, choose(2,10)).
# profile(126, choose(3,9)).
# profile(127, choose(1,1)).
# profile(127, choose(2,10)).
# profile(127, choose(3,10)).
# profile(128, choose(1,1)).
# profile(128, choose(2,10)).
# profile(128, choose(3,11)).
# profile(129, choose(1,1)).
# profile(129, choose(2,10)).
# profile(129, choose(3,12)).
# profile(130, choose(1,1)).
# profile(130, choose(2,10)).
# profile(130, choose(3,13)).
# profile(131, choose(1,1)).
# profile(131, choose(2,11)).
# profile(131, choose(3,1)).
# profile(132, choose(1,1)).
# profile(132, choose(2,11)).
# profile(132, choose(3,2)).
# profile(133, choose(1,1)).
# profile(133, choose(2,11)).
# profile(133, choose(3,3)).
# profile(134, choose(1,1)).
# profile(134, choose(2,11)).
# profile(134, choose(3,4)).
# profile(135, choose(1,1)).
# profile(135, choose(2,11)).
# profile(135, choose(3,5)).
# profile(136, choose(1,1)).
# profile(136, choose(2,11)).
# profile(136, choose(3,6)).
# profile(137, choose(1,1)).
# profile(137, choose(2,11)).
# profile(137, choose(3,7)).
# profile(138, choose(1,1)).
# profile(138, choose(2,11)).
# profile(138, choose(3,8)).
# profile(139, choose(1,1)).
# profile(139, choose(2,11)).
# profile(139, choose(3,9)).
# profile(140, choose(1,1)).
# profile(140, choose(2,11)).
# profile(140, choose(3,10)).
# profile(141, choose(1,1)).
# profile(141, choose(2,11)).
# profile(141, choose(3,11)).
# profile(142, choose(1,1)).
# profile(142, choose(2,11)).
# profile(142, choose(3,12)).
# profile(143, choose(1,1)).
# profile(143, choose(2,11)).
# profile(143, choose(3,13)).
# profile(144, choose(1,1)).
# profile(144, choose(2,12)).
# profile(144, choose(3,1)).
# profile(145, choose(1,1)).
# profile(145, choose(2,12)).
# profile(145, choose(3,2)).
# profile(146, choose(1,1)).
# profile(146, choose(2,12)).
# profile(146, choose(3,3)).
# profile(147, choose(1,1)).
# profile(147, choose(2,12)).
# profile(147, choose(3,4)).
# profile(148, choose(1,1)).
# profile(148, choose(2,12)).
# profile(148, choose(3,5)).
# profile(149, choose(1,1)).
# profile(149, choose(2,12)).
# profile(149, choose(3,6)).
# profile(150, choose(1,1)).
# profile(150, choose(2,12)).
# profile(150, choose(3,7)).
# profile(151, choose(1,1)).
# profile(151, choose(2,12)).
# profile(151, choose(3,8)).
# profile(152, choose(1,1)).
# profile(152, choose(2,12)).
# profile(152, choose(3,9)).
# profile(153, choose(1,1)).
# profile(153, choose(2,12)).
# profile(153, choose(3,10)).
# profile(154, choose(1,1)).
# profile(154, choose(2,12)).
# profile(154, choose(3,11)).
# profile(155, choose(1,1)).
# profile(155, choose(2,12)).
# profile(155, choose(3,12)).
# profile(156, choose(1,1)).
# profile(156, choose(2,12)).
# profile(156, choose(3,13)).
# profile(157, choose(1,1)).
# profile(157, choose(2,13)).
# profile(157, choose(3,1)).
# profile(158, choose(1,1)).
# profile(158, choose(2,13)).
# profile(158, choose(3,2)).
# profile(159, choose(1,1)).
# profile(159, choose(2,13)).
# profile(159, choose(3,3)).
# profile(160, choose(1,1)).
# profile(160, choose(2,13)).
# profile(160, choose(3,4)).
# profile(161, choose(1,1)).
# profile(161, choose(2,13)).
# profile(161, choose(3,5)).
# profile(162, choose(1,1)).
# profile(162, choose(2,13)).
# profile(162, choose(3,6)).
# profile(163, choose(1,1)).
# profile(163, choose(2,13)).
# profile(163, choose(3,7)).
# profile(164, choose(1,1)).
# profile(164, choose(2,13)).
# profile(164, choose(3,8)).
# profile(165, choose(1,1)).
# profile(165, choose(2,13)).
# profile(165, choose(3,9)).
# profile(166, choose(1,1)).
# profile(166, choose(2,13)).
# profile(166, choose(3,10)).
# profile(167, choose(1,1)).
# profile(167, choose(2,13)).
# profile(167, choose(3,11)).
# profile(168, choose(1,1)).
# profile(168, choose(2,13)).
# profile(168, choose(3,12)).
# profile(169, choose(1,1)).
# profile(169, choose(2,13)).
# profile(169, choose(3,13)).
# profile(170, choose(1,2)).
# profile(170, choose(2,1)).
# profile(170, choose(3,1)).
# profile(171, choose(1,2)).
# profile(171, choose(2,1)).
# profile(171, choose(3,2)).
# profile(172, choose(1,2)).
# profile(172, choose(2,1)).
# profile(172, choose(3,3)).
# profile(173, choose(1,2)).
# profile(173, choose(2,1)).
# profile(173, choose(3,4)).
# profile(174, choose(1,2)).
# profile(174, choose(2,1)).
# profile(174, choose(3,5)).
# profile(175, choose(1,2)).
# profile(175, choose(2,1)).
# profile(175, choose(3,6)).
# profile(176, choose(1,2)).
# profile(176, choose(2,1)).
# profile(176, choose(3,7)).
# profile(177, choose(1,2)).
# profile(177, choose(2,1)).
# profile(177, choose(3,8)).
# profile(178, choose(1,2)).
# profile(178, choose(2,1)).
# profile(178, choose(3,9)).
# profile(179, choose(1,2)).
# profile(179, choose(2,1)).
# profile(179, choose(3,10)).
# profile(180, choose(1,2)).
# profile(180, choose(2,1)).
# profile(180, choose(3,11)).
# profile(181, choose(1,2)).
# profile(181, choose(2,1)).
# profile(181, choose(3,12)).
# profile(182, choose(1,2)).
# profile(182, choose(2,1)).
# profile(182, choose(3,13)).
# profile(183, choose(1,2)).
# profile(183, choose(2,2)).
# profile(183, choose(3,1)).
# profile(184, choose(1,2)).
# profile(184, choose(2,2)).
# profile(184, choose(3,2)).
# profile(185, choose(1,2)).
# profile(185, choose(2,2)).
# profile(185, choose(3,3)).
# profile(186, choose(1,2)).
# profile(186, choose(2,2)).
# profile(186, choose(3,4)).
# profile(187, choose(1,2)).
# profile(187, choose(2,2)).
# profile(187, choose(3,5)).
# profile(188, choose(1,2)).
# profile(188, choose(2,2)).
# profile(188, choose(3,6)).
# profile(189, choose(1,2)).
# profile(189, choose(2,2)).
# profile(189, choose(3,7)).
# profile(190, choose(1,2)).
# profile(190, choose(2,2)).
# profile(190, choose(3,8)).
# profile(191, choose(1,2)).
# profile(191, choose(2,2)).
# profile(191, choose(3,9)).
# profile(192, choose(1,2)).
# profile(192, choose(2,2)).
# profile(192, choose(3,10)).
# profile(193, choose(1,2)).
# profile(193, choose(2,2)).
# profile(193, choose(3,11)).
# profile(194, choose(1,2)).
# profile(194, choose(2,2)).
# profile(194, choose(3,12)).
# profile(195, choose(1,2)).
# profile(195, choose(2,2)).
# profile(195, choose(3,13)).
# profile(196, choose(1,2)).
# profile(196, choose(2,3)).
# profile(196, choose(3,1)).
# profile(197, choose(1,2)).
# profile(197, choose(2,3)).
# profile(197, choose(3,2)).
# profile(198, choose(1,2)).
# profile(198, choose(2,3)).
# profile(198, choose(3,3)).
# profile(199, choose(1,2)).
# profile(199, choose(2,3)).
# profile(199, choose(3,4)).
# profile(200, choose(1,2)).
# profile(200, choose(2,3)).
# profile(200, choose(3,5)).
# profile(201, choose(1,2)).
# profile(201, choose(2,3)).
# profile(201, choose(3,6)).
# profile(202, choose(1,2)).
# profile(202, choose(2,3)).
# profile(202, choose(3,7)).
# profile(203, choose(1,2)).
# profile(203, choose(2,3)).
# profile(203, choose(3,8)).
# profile(204, choose(1,2)).
# profile(204, choose(2,3)).
# profile(204, choose(3,9)).
# profile(205, choose(1,2)).
# profile(205, choose(2,3)).
# profile(205, choose(3,10)).
# profile(206, choose(1,2)).
# profile(206, choose(2,3)).
# profile(206, choose(3,11)).
# profile(207, choose(1,2)).
# profile(207, choose(2,3)).
# profile(207, choose(3,12)).
# profile(208, choose(1,2)).
# profile(208, choose(2,3)).
# profile(208, choose(3,13)).
# profile(209, choose(1,2)).
# profile(209, choose(2,4)).
# profile(209, choose(3,1)).
# profile(210, choose(1,2)).
# profile(210, choose(2,4)).
# profile(210, choose(3,2)).
# profile(211, choose(1,2)).
# profile(211, choose(2,4)).
# profile(211, choose(3,3)).
# profile(212, choose(1,2)).
# profile(212, choose(2,4)).
# profile(212, choose(3,4)).
# profile(213, choose(1,2)).
# profile(213, choose(2,4)).
# profile(213, choose(3,5)).
# profile(214, choose(1,2)).
# profile(214, choose(2,4)).
# profile(214, choose(3,6)).
# profile(215, choose(1,2)).
# profile(215, choose(2,4)).
# profile(215, choose(3,7)).
# profile(216, choose(1,2)).
# profile(216, choose(2,4)).
# profile(216, choose(3,8)).
# profile(217, choose(1,2)).
# profile(217, choose(2,4)).
# profile(217, choose(3,9)).
# profile(218, choose(1,2)).
# profile(218, choose(2,4)).
# profile(218, choose(3,10)).
# profile(219, choose(1,2)).
# profile(219, choose(2,4)).
# profile(219, choose(3,11)).
# profile(220, choose(1,2)).
# profile(220, choose(2,4)).
# profile(220, choose(3,12)).
# profile(221, choose(1,2)).
# profile(221, choose(2,4)).
# profile(221, choose(3,13)).
# profile(222, choose(1,2)).
# profile(222, choose(2,5)).
# profile(222, choose(3,1)).
# profile(223, choose(1,2)).
# profile(223, choose(2,5)).
# profile(223, choose(3,2)).
# profile(224, choose(1,2)).
# profile(224, choose(2,5)).
# profile(224, choose(3,3)).
# profile(225, choose(1,2)).
# profile(225, choose(2,5)).
# profile(225, choose(3,4)).
# profile(226, choose(1,2)).
# profile(226, choose(2,5)).
# profile(226, choose(3,5)).
# profile(227, choose(1,2)).
# profile(227, choose(2,5)).
# profile(227, choose(3,6)).
# profile(228, choose(1,2)).
# profile(228, choose(2,5)).
# profile(228, choose(3,7)).
# profile(229, choose(1,2)).
# profile(229, choose(2,5)).
# profile(229, choose(3,8)).
# profile(230, choose(1,2)).
# profile(230, choose(2,5)).
# profile(230, choose(3,9)).
# profile(231, choose(1,2)).
# profile(231, choose(2,5)).
# profile(231, choose(3,10)).
# profile(232, choose(1,2)).
# profile(232, choose(2,5)).
# profile(232, choose(3,11)).
# profile(233, choose(1,2)).
# profile(233, choose(2,5)).
# profile(233, choose(3,12)).
# profile(234, choose(1,2)).
# profile(234, choose(2,5)).
# profile(234, choose(3,13)).
# profile(235, choose(1,2)).
# profile(235, choose(2,6)).
# profile(235, choose(3,1)).
# profile(236, choose(1,2)).
# profile(236, choose(2,6)).
# profile(236, choose(3,2)).
# profile(237, choose(1,2)).
# profile(237, choose(2,6)).
# profile(237, choose(3,3)).
# profile(238, choose(1,2)).
# profile(238, choose(2,6)).
# profile(238, choose(3,4)).
# profile(239, choose(1,2)).
# profile(239, choose(2,6)).
# profile(239, choose(3,5)).
# profile(240, choose(1,2)).
# profile(240, choose(2,6)).
# profile(240, choose(3,6)).
# profile(241, choose(1,2)).
# profile(241, choose(2,6)).
# profile(241, choose(3,7)).
# profile(242, choose(1,2)).
# profile(242, choose(2,6)).
# profile(242, choose(3,8)).
# profile(243, choose(1,2)).
# profile(243, choose(2,6)).
# profile(243, choose(3,9)).
# profile(244, choose(1,2)).
# profile(244, choose(2,6)).
# profile(244, choose(3,10)).
# profile(245, choose(1,2)).
# profile(245, choose(2,6)).
# profile(245, choose(3,11)).
# profile(246, choose(1,2)).
# profile(246, choose(2,6)).
# profile(246, choose(3,12)).
# profile(247, choose(1,2)).
# profile(247, choose(2,6)).
# profile(247, choose(3,13)).
# profile(248, choose(1,2)).
# profile(248, choose(2,7)).
# profile(248, choose(3,1)).
# profile(249, choose(1,2)).
# profile(249, choose(2,7)).
# profile(249, choose(3,2)).
# profile(250, choose(1,2)).
# profile(250, choose(2,7)).
# profile(250, choose(3,3)).
# profile(251, choose(1,2)).
# profile(251, choose(2,7)).
# profile(251, choose(3,4)).
# profile(252, choose(1,2)).
# profile(252, choose(2,7)).
# profile(252, choose(3,5)).
# profile(253, choose(1,2)).
# profile(253, choose(2,7)).
# profile(253, choose(3,6)).
# profile(254, choose(1,2)).
# profile(254, choose(2,7)).
# profile(254, choose(3,7)).
# profile(255, choose(1,2)).
# profile(255, choose(2,7)).
# profile(255, choose(3,8)).
# profile(256, choose(1,2)).
# profile(256, choose(2,7)).
# profile(256, choose(3,9)).
# profile(257, choose(1,2)).
# profile(257, choose(2,7)).
# profile(257, choose(3,10)).
# profile(258, choose(1,2)).
# profile(258, choose(2,7)).
# profile(258, choose(3,11)).
# profile(259, choose(1,2)).
# profile(259, choose(2,7)).
# profile(259, choose(3,12)).
# profile(260, choose(1,2)).
# profile(260, choose(2,7)).
# profile(260, choose(3,13)).
# profile(261, choose(1,2)).
# profile(261, choose(2,8)).
# profile(261, choose(3,1)).
# profile(262, choose(1,2)).
# profile(262, choose(2,8)).
# profile(262, choose(3,2)).
# profile(263, choose(1,2)).
# profile(263, choose(2,8)).
# profile(263, choose(3,3)).
# profile(264, choose(1,2)).
# profile(264, choose(2,8)).
# profile(264, choose(3,4)).
# profile(265, choose(1,2)).
# profile(265, choose(2,8)).
# profile(265, choose(3,5)).
# profile(266, choose(1,2)).
# profile(266, choose(2,8)).
# profile(266, choose(3,6)).
# profile(267, choose(1,2)).
# profile(267, choose(2,8)).
# profile(267, choose(3,7)).
# profile(268, choose(1,2)).
# profile(268, choose(2,8)).
# profile(268, choose(3,8)).
# profile(269, choose(1,2)).
# profile(269, choose(2,8)).
# profile(269, choose(3,9)).
# profile(270, choose(1,2)).
# profile(270, choose(2,8)).
# profile(270, choose(3,10)).
# profile(271, choose(1,2)).
# profile(271, choose(2,8)).
# profile(271, choose(3,11)).
# profile(272, choose(1,2)).
# profile(272, choose(2,8)).
# profile(272, choose(3,12)).
# profile(273, choose(1,2)).
# profile(273, choose(2,8)).
# profile(273, choose(3,13)).
# profile(274, choose(1,2)).
# profile(274, choose(2,9)).
# profile(274, choose(3,1)).
# profile(275, choose(1,2)).
# profile(275, choose(2,9)).
# profile(275, choose(3,2)).
# profile(276, choose(1,2)).
# profile(276, choose(2,9)).
# profile(276, choose(3,3)).
# profile(277, choose(1,2)).
# profile(277, choose(2,9)).
# profile(277, choose(3,4)).
# profile(278, choose(1,2)).
# profile(278, choose(2,9)).
# profile(278, choose(3,5)).
# profile(279, choose(1,2)).
# profile(279, choose(2,9)).
# profile(279, choose(3,6)).
# profile(280, choose(1,2)).
# profile(280, choose(2,9)).
# profile(280, choose(3,7)).
# profile(281, choose(1,2)).
# profile(281, choose(2,9)).
# profile(281, choose(3,8)).
# profile(282, choose(1,2)).
# profile(282, choose(2,9)).
# profile(282, choose(3,9)).
# profile(283, choose(1,2)).
# profile(283, choose(2,9)).
# profile(283, choose(3,10)).
# profile(284, choose(1,2)).
# profile(284, choose(2,9)).
# profile(284, choose(3,11)).
# profile(285, choose(1,2)).
# profile(285, choose(2,9)).
# profile(285, choose(3,12)).
# profile(286, choose(1,2)).
# profile(286, choose(2,9)).
# profile(286, choose(3,13)).
# profile(287, choose(1,2)).
# profile(287, choose(2,10)).
# profile(287, choose(3,1)).
# profile(288, choose(1,2)).
# profile(288, choose(2,10)).
# profile(288, choose(3,2)).
# profile(289, choose(1,2)).
# profile(289, choose(2,10)).
# profile(289, choose(3,3)).
# profile(290, choose(1,2)).
# profile(290, choose(2,10)).
# profile(290, choose(3,4)).
# profile(291, choose(1,2)).
# profile(291, choose(2,10)).
# profile(291, choose(3,5)).
# profile(292, choose(1,2)).
# profile(292, choose(2,10)).
# profile(292, choose(3,6)).
# profile(293, choose(1,2)).
# profile(293, choose(2,10)).
# profile(293, choose(3,7)).
# profile(294, choose(1,2)).
# profile(294, choose(2,10)).
# profile(294, choose(3,8)).
# profile(295, choose(1,2)).
# profile(295, choose(2,10)).
# profile(295, choose(3,9)).
# profile(296, choose(1,2)).
# profile(296, choose(2,10)).
# profile(296, choose(3,10)).
# profile(297, choose(1,2)).
# profile(297, choose(2,10)).
# profile(297, choose(3,11)).
# profile(298, choose(1,2)).
# profile(298, choose(2,10)).
# profile(298, choose(3,12)).
# profile(299, choose(1,2)).
# profile(299, choose(2,10)).
# profile(299, choose(3,13)).
# profile(300, choose(1,2)).
# profile(300, choose(2,11)).
# profile(300, choose(3,1)).
# profile(301, choose(1,2)).
# profile(301, choose(2,11)).
# profile(301, choose(3,2)).
# profile(302, choose(1,2)).
# profile(302, choose(2,11)).
# profile(302, choose(3,3)).
# profile(303, choose(1,2)).
# profile(303, choose(2,11)).
# profile(303, choose(3,4)).
# profile(304, choose(1,2)).
# profile(304, choose(2,11)).
# profile(304, choose(3,5)).
# profile(305, choose(1,2)).
# profile(305, choose(2,11)).
# profile(305, choose(3,6)).
# profile(306, choose(1,2)).
# profile(306, choose(2,11)).
# profile(306, choose(3,7)).
# profile(307, choose(1,2)).
# profile(307, choose(2,11)).
# profile(307, choose(3,8)).
# profile(308, choose(1,2)).
# profile(308, choose(2,11)).
# profile(308, choose(3,9)).
# profile(309, choose(1,2)).
# profile(309, choose(2,11)).
# profile(309, choose(3,10)).
# profile(310, choose(1,2)).
# profile(310, choose(2,11)).
# profile(310, choose(3,11)).
# profile(311, choose(1,2)).
# profile(311, choose(2,11)).
# profile(311, choose(3,12)).
# profile(312, choose(1,2)).
# profile(312, choose(2,11)).
# profile(312, choose(3,13)).
# profile(313, choose(1,2)).
# profile(313, choose(2,12)).
# profile(313, choose(3,1)).
# profile(314, choose(1,2)).
# profile(314, choose(2,12)).
# profile(314, choose(3,2)).
# profile(315, choose(1,2)).
# profile(315, choose(2,12)).
# profile(315, choose(3,3)).
# profile(316, choose(1,2)).
# profile(316, choose(2,12)).
# profile(316, choose(3,4)).
# profile(317, choose(1,2)).
# profile(317, choose(2,12)).
# profile(317, choose(3,5)).
# profile(318, choose(1,2)).
# profile(318, choose(2,12)).
# profile(318, choose(3,6)).
# profile(319, choose(1,2)).
# profile(319, choose(2,12)).
# profile(319, choose(3,7)).
# profile(320, choose(1,2)).
# profile(320, choose(2,12)).
# profile(320, choose(3,8)).
# profile(321, choose(1,2)).
# profile(321, choose(2,12)).
# profile(321, choose(3,9)).
# profile(322, choose(1,2)).
# profile(322, choose(2,12)).
# profile(322, choose(3,10)).
# profile(323, choose(1,2)).
# profile(323, choose(2,12)).
# profile(323, choose(3,11)).
# profile(324, choose(1,2)).
# profile(324, choose(2,12)).
# profile(324, choose(3,12)).
# profile(325, choose(1,2)).
# profile(325, choose(2,12)).
# profile(325, choose(3,13)).
# profile(326, choose(1,2)).
# profile(326, choose(2,13)).
# profile(326, choose(3,1)).
# profile(327, choose(1,2)).
# profile(327, choose(2,13)).
# profile(327, choose(3,2)).
# profile(328, choose(1,2)).
# profile(328, choose(2,13)).
# profile(328, choose(3,3)).
# profile(329, choose(1,2)).
# profile(329, choose(2,13)).
# profile(329, choose(3,4)).
# profile(330, choose(1,2)).
# profile(330, choose(2,13)).
# profile(330, choose(3,5)).
# profile(331, choose(1,2)).
# profile(331, choose(2,13)).
# profile(331, choose(3,6)).
# profile(332, choose(1,2)).
# profile(332, choose(2,13)).
# profile(332, choose(3,7)).
# profile(333, choose(1,2)).
# profile(333, choose(2,13)).
# profile(333, choose(3,8)).
# profile(334, choose(1,2)).
# profile(334, choose(2,13)).
# profile(334, choose(3,9)).
# profile(335, choose(1,2)).
# profile(335, choose(2,13)).
# profile(335, choose(3,10)).
# profile(336, choose(1,2)).
# profile(336, choose(2,13)).
# profile(336, choose(3,11)).
# profile(337, choose(1,2)).
# profile(337, choose(2,13)).
# profile(337, choose(3,12)).
# profile(338, choose(1,2)).
# profile(338, choose(2,13)).
# profile(338, choose(3,13)).
# profile(339, choose(1,3)).
# profile(339, choose(2,1)).
# profile(339, choose(3,1)).
# profile(340, choose(1,3)).
# profile(340, choose(2,1)).
# profile(340, choose(3,2)).
# profile(341, choose(1,3)).
# profile(341, choose(2,1)).
# profile(341, choose(3,3)).
# profile(342, choose(1,3)).
# profile(342, choose(2,1)).
# profile(342, choose(3,4)).
# profile(343, choose(1,3)).
# profile(343, choose(2,1)).
# profile(343, choose(3,5)).
# profile(344, choose(1,3)).
# profile(344, choose(2,1)).
# profile(344, choose(3,6)).
# profile(345, choose(1,3)).
# profile(345, choose(2,1)).
# profile(345, choose(3,7)).
# profile(346, choose(1,3)).
# profile(346, choose(2,1)).
# profile(346, choose(3,8)).
# profile(347, choose(1,3)).
# profile(347, choose(2,1)).
# profile(347, choose(3,9)).
# profile(348, choose(1,3)).
# profile(348, choose(2,1)).
# profile(348, choose(3,10)).
# profile(349, choose(1,3)).
# profile(349, choose(2,1)).
# profile(349, choose(3,11)).
# profile(350, choose(1,3)).
# profile(350, choose(2,1)).
# profile(350, choose(3,12)).
# profile(351, choose(1,3)).
# profile(351, choose(2,1)).
# profile(351, choose(3,13)).
# profile(352, choose(1,3)).
# profile(352, choose(2,2)).
# profile(352, choose(3,1)).
# profile(353, choose(1,3)).
# profile(353, choose(2,2)).
# profile(353, choose(3,2)).
# profile(354, choose(1,3)).
# profile(354, choose(2,2)).
# profile(354, choose(3,3)).
# profile(355, choose(1,3)).
# profile(355, choose(2,2)).
# profile(355, choose(3,4)).
# profile(356, choose(1,3)).
# profile(356, choose(2,2)).
# profile(356, choose(3,5)).
# profile(357, choose(1,3)).
# profile(357, choose(2,2)).
# profile(357, choose(3,6)).
# profile(358, choose(1,3)).
# profile(358, choose(2,2)).
# profile(358, choose(3,7)).
# profile(359, choose(1,3)).
# profile(359, choose(2,2)).
# profile(359, choose(3,8)).
# profile(360, choose(1,3)).
# profile(360, choose(2,2)).
# profile(360, choose(3,9)).
# profile(361, choose(1,3)).
# profile(361, choose(2,2)).
# profile(361, choose(3,10)).
# profile(362, choose(1,3)).
# profile(362, choose(2,2)).
# profile(362, choose(3,11)).
# profile(363, choose(1,3)).
# profile(363, choose(2,2)).
# profile(363, choose(3,12)).
# profile(364, choose(1,3)).
# profile(364, choose(2,2)).
# profile(364, choose(3,13)).
# profile(365, choose(1,3)).
# profile(365, choose(2,3)).
# profile(365, choose(3,1)).
# profile(366, choose(1,3)).
# profile(366, choose(2,3)).
# profile(366, choose(3,2)).
# profile(367, choose(1,3)).
# profile(367, choose(2,3)).
# profile(367, choose(3,3)).
# profile(368, choose(1,3)).
# profile(368, choose(2,3)).
# profile(368, choose(3,4)).
# profile(369, choose(1,3)).
# profile(369, choose(2,3)).
# profile(369, choose(3,5)).
# profile(370, choose(1,3)).
# profile(370, choose(2,3)).
# profile(370, choose(3,6)).
# profile(371, choose(1,3)).
# profile(371, choose(2,3)).
# profile(371, choose(3,7)).
# profile(372, choose(1,3)).
# profile(372, choose(2,3)).
# profile(372, choose(3,8)).
# profile(373, choose(1,3)).
# profile(373, choose(2,3)).
# profile(373, choose(3,9)).
# profile(374, choose(1,3)).
# profile(374, choose(2,3)).
# profile(374, choose(3,10)).
# profile(375, choose(1,3)).
# profile(375, choose(2,3)).
# profile(375, choose(3,11)).
# profile(376, choose(1,3)).
# profile(376, choose(2,3)).
# profile(376, choose(3,12)).
# profile(377, choose(1,3)).
# profile(377, choose(2,3)).
# profile(377, choose(3,13)).
# profile(378, choose(1,3)).
# profile(378, choose(2,4)).
# profile(378, choose(3,1)).
# profile(379, choose(1,3)).
# profile(379, choose(2,4)).
# profile(379, choose(3,2)).
# profile(380, choose(1,3)).
# profile(380, choose(2,4)).
# profile(380, choose(3,3)).
# profile(381, choose(1,3)).
# profile(381, choose(2,4)).
# profile(381, choose(3,4)).
# profile(382, choose(1,3)).
# profile(382, choose(2,4)).
# profile(382, choose(3,5)).
# profile(383, choose(1,3)).
# profile(383, choose(2,4)).
# profile(383, choose(3,6)).
# profile(384, choose(1,3)).
# profile(384, choose(2,4)).
# profile(384, choose(3,7)).
# profile(385, choose(1,3)).
# profile(385, choose(2,4)).
# profile(385, choose(3,8)).
# profile(386, choose(1,3)).
# profile(386, choose(2,4)).
# profile(386, choose(3,9)).
# profile(387, choose(1,3)).
# profile(387, choose(2,4)).
# profile(387, choose(3,10)).
# profile(388, choose(1,3)).
# profile(388, choose(2,4)).
# profile(388, choose(3,11)).
# profile(389, choose(1,3)).
# profile(389, choose(2,4)).
# profile(389, choose(3,12)).
# profile(390, choose(1,3)).
# profile(390, choose(2,4)).
# profile(390, choose(3,13)).
# profile(391, choose(1,3)).
# profile(391, choose(2,5)).
# profile(391, choose(3,1)).
# profile(392, choose(1,3)).
# profile(392, choose(2,5)).
# profile(392, choose(3,2)).
# profile(393, choose(1,3)).
# profile(393, choose(2,5)).
# profile(393, choose(3,3)).
# profile(394, choose(1,3)).
# profile(394, choose(2,5)).
# profile(394, choose(3,4)).
# profile(395, choose(1,3)).
# profile(395, choose(2,5)).
# profile(395, choose(3,5)).
# profile(396, choose(1,3)).
# profile(396, choose(2,5)).
# profile(396, choose(3,6)).
# profile(397, choose(1,3)).
# profile(397, choose(2,5)).
# profile(397, choose(3,7)).
# profile(398, choose(1,3)).
# profile(398, choose(2,5)).
# profile(398, choose(3,8)).
# profile(399, choose(1,3)).
# profile(399, choose(2,5)).
# profile(399, choose(3,9)).
# profile(400, choose(1,3)).
# profile(400, choose(2,5)).
# profile(400, choose(3,10)).
# profile(401, choose(1,3)).
# profile(401, choose(2,5)).
# profile(401, choose(3,11)).
# profile(402, choose(1,3)).
# profile(402, choose(2,5)).
# profile(402, choose(3,12)).
# profile(403, choose(1,3)).
# profile(403, choose(2,5)).
# profile(403, choose(3,13)).
# profile(404, choose(1,3)).
# profile(404, choose(2,6)).
# profile(404, choose(3,1)).
# profile(405, choose(1,3)).
# profile(405, choose(2,6)).
# profile(405, choose(3,2)).
# profile(406, choose(1,3)).
# profile(406, choose(2,6)).
# profile(406, choose(3,3)).
# profile(407, choose(1,3)).
# profile(407, choose(2,6)).
# profile(407, choose(3,4)).
# profile(408, choose(1,3)).
# profile(408, choose(2,6)).
# profile(408, choose(3,5)).
# profile(409, choose(1,3)).
# profile(409, choose(2,6)).
# profile(409, choose(3,6)).
# profile(410, choose(1,3)).
# profile(410, choose(2,6)).
# profile(410, choose(3,7)).
# profile(411, choose(1,3)).
# profile(411, choose(2,6)).
# profile(411, choose(3,8)).
# profile(412, choose(1,3)).
# profile(412, choose(2,6)).
# profile(412, choose(3,9)).
# profile(413, choose(1,3)).
# profile(413, choose(2,6)).
# profile(413, choose(3,10)).
# profile(414, choose(1,3)).
# profile(414, choose(2,6)).
# profile(414, choose(3,11)).
# profile(415, choose(1,3)).
# profile(415, choose(2,6)).
# profile(415, choose(3,12)).
# profile(416, choose(1,3)).
# profile(416, choose(2,6)).
# profile(416, choose(3,13)).
# profile(417, choose(1,3)).
# profile(417, choose(2,7)).
# profile(417, choose(3,1)).
# profile(418, choose(1,3)).
# profile(418, choose(2,7)).
# profile(418, choose(3,2)).
# profile(419, choose(1,3)).
# profile(419, choose(2,7)).
# profile(419, choose(3,3)).
# profile(420, choose(1,3)).
# profile(420, choose(2,7)).
# profile(420, choose(3,4)).
# profile(421, choose(1,3)).
# profile(421, choose(2,7)).
# profile(421, choose(3,5)).
# profile(422, choose(1,3)).
# profile(422, choose(2,7)).
# profile(422, choose(3,6)).
# profile(423, choose(1,3)).
# profile(423, choose(2,7)).
# profile(423, choose(3,7)).
# profile(424, choose(1,3)).
# profile(424, choose(2,7)).
# profile(424, choose(3,8)).
# profile(425, choose(1,3)).
# profile(425, choose(2,7)).
# profile(425, choose(3,9)).
# profile(426, choose(1,3)).
# profile(426, choose(2,7)).
# profile(426, choose(3,10)).
# profile(427, choose(1,3)).
# profile(427, choose(2,7)).
# profile(427, choose(3,11)).
# profile(428, choose(1,3)).
# profile(428, choose(2,7)).
# profile(428, choose(3,12)).
# profile(429, choose(1,3)).
# profile(429, choose(2,7)).
# profile(429, choose(3,13)).
# profile(430, choose(1,3)).
# profile(430, choose(2,8)).
# profile(430, choose(3,1)).
# profile(431, choose(1,3)).
# profile(431, choose(2,8)).
# profile(431, choose(3,2)).
# profile(432, choose(1,3)).
# profile(432, choose(2,8)).
# profile(432, choose(3,3)).
# profile(433, choose(1,3)).
# profile(433, choose(2,8)).
# profile(433, choose(3,4)).
# profile(434, choose(1,3)).
# profile(434, choose(2,8)).
# profile(434, choose(3,5)).
# profile(435, choose(1,3)).
# profile(435, choose(2,8)).
# profile(435, choose(3,6)).
# profile(436, choose(1,3)).
# profile(436, choose(2,8)).
# profile(436, choose(3,7)).
# profile(437, choose(1,3)).
# profile(437, choose(2,8)).
# profile(437, choose(3,8)).
# profile(438, choose(1,3)).
# profile(438, choose(2,8)).
# profile(438, choose(3,9)).
# profile(439, choose(1,3)).
# profile(439, choose(2,8)).
# profile(439, choose(3,10)).
# profile(440, choose(1,3)).
# profile(440, choose(2,8)).
# profile(440, choose(3,11)).
# profile(441, choose(1,3)).
# profile(441, choose(2,8)).
# profile(441, choose(3,12)).
# profile(442, choose(1,3)).
# profile(442, choose(2,8)).
# profile(442, choose(3,13)).
# profile(443, choose(1,3)).
# profile(443, choose(2,9)).
# profile(443, choose(3,1)).
# profile(444, choose(1,3)).
# profile(444, choose(2,9)).
# profile(444, choose(3,2)).
# profile(445, choose(1,3)).
# profile(445, choose(2,9)).
# profile(445, choose(3,3)).
# profile(446, choose(1,3)).
# profile(446, choose(2,9)).
# profile(446, choose(3,4)).
# profile(447, choose(1,3)).
# profile(447, choose(2,9)).
# profile(447, choose(3,5)).
# profile(448, choose(1,3)).
# profile(448, choose(2,9)).
# profile(448, choose(3,6)).
# profile(449, choose(1,3)).
# profile(449, choose(2,9)).
# profile(449, choose(3,7)).
# profile(450, choose(1,3)).
# profile(450, choose(2,9)).
# profile(450, choose(3,8)).
# profile(451, choose(1,3)).
# profile(451, choose(2,9)).
# profile(451, choose(3,9)).
# profile(452, choose(1,3)).
# profile(452, choose(2,9)).
# profile(452, choose(3,10)).
# profile(453, choose(1,3)).
# profile(453, choose(2,9)).
# profile(453, choose(3,11)).
# profile(454, choose(1,3)).
# profile(454, choose(2,9)).
# profile(454, choose(3,12)).
# profile(455, choose(1,3)).
# profile(455, choose(2,9)).
# profile(455, choose(3,13)).
# profile(456, choose(1,3)).
# profile(456, choose(2,10)).
# profile(456, choose(3,1)).
# profile(457, choose(1,3)).
# profile(457, choose(2,10)).
# profile(457, choose(3,2)).
# profile(458, choose(1,3)).
# profile(458, choose(2,10)).
# profile(458, choose(3,3)).
# profile(459, choose(1,3)).
# profile(459, choose(2,10)).
# profile(459, choose(3,4)).
# profile(460, choose(1,3)).
# profile(460, choose(2,10)).
# profile(460, choose(3,5)).
# profile(461, choose(1,3)).
# profile(461, choose(2,10)).
# profile(461, choose(3,6)).
# profile(462, choose(1,3)).
# profile(462, choose(2,10)).
# profile(462, choose(3,7)).
# profile(463, choose(1,3)).
# profile(463, choose(2,10)).
# profile(463, choose(3,8)).
# profile(464, choose(1,3)).
# profile(464, choose(2,10)).
# profile(464, choose(3,9)).
# profile(465, choose(1,3)).
# profile(465, choose(2,10)).
# profile(465, choose(3,10)).
# profile(466, choose(1,3)).
# profile(466, choose(2,10)).
# profile(466, choose(3,11)).
# profile(467, choose(1,3)).
# profile(467, choose(2,10)).
# profile(467, choose(3,12)).
# profile(468, choose(1,3)).
# profile(468, choose(2,10)).
# profile(468, choose(3,13)).
# profile(469, choose(1,3)).
# profile(469, choose(2,11)).
# profile(469, choose(3,1)).
# profile(470, choose(1,3)).
# profile(470, choose(2,11)).
# profile(470, choose(3,2)).
# profile(471, choose(1,3)).
# profile(471, choose(2,11)).
# profile(471, choose(3,3)).
# profile(472, choose(1,3)).
# profile(472, choose(2,11)).
# profile(472, choose(3,4)).
# profile(473, choose(1,3)).
# profile(473, choose(2,11)).
# profile(473, choose(3,5)).
# profile(474, choose(1,3)).
# profile(474, choose(2,11)).
# profile(474, choose(3,6)).
# profile(475, choose(1,3)).
# profile(475, choose(2,11)).
# profile(475, choose(3,7)).
# profile(476, choose(1,3)).
# profile(476, choose(2,11)).
# profile(476, choose(3,8)).
# profile(477, choose(1,3)).
# profile(477, choose(2,11)).
# profile(477, choose(3,9)).
# profile(478, choose(1,3)).
# profile(478, choose(2,11)).
# profile(478, choose(3,10)).
# profile(479, choose(1,3)).
# profile(479, choose(2,11)).
# profile(479, choose(3,11)).
# profile(480, choose(1,3)).
# profile(480, choose(2,11)).
# profile(480, choose(3,12)).
# profile(481, choose(1,3)).
# profile(481, choose(2,11)).
# profile(481, choose(3,13)).
# profile(482, choose(1,3)).
# profile(482, choose(2,12)).
# profile(482, choose(3,1)).
# profile(483, choose(1,3)).
# profile(483, choose(2,12)).
# profile(483, choose(3,2)).
# profile(484, choose(1,3)).
# profile(484, choose(2,12)).
# profile(484, choose(3,3)).
# profile(485, choose(1,3)).
# profile(485, choose(2,12)).
# profile(485, choose(3,4)).
# profile(486, choose(1,3)).
# profile(486, choose(2,12)).
# profile(486, choose(3,5)).
# profile(487, choose(1,3)).
# profile(487, choose(2,12)).
# profile(487, choose(3,6)).
# profile(488, choose(1,3)).
# profile(488, choose(2,12)).
# profile(488, choose(3,7)).
# profile(489, choose(1,3)).
# profile(489, choose(2,12)).
# profile(489, choose(3,8)).
# profile(490, choose(1,3)).
# profile(490, choose(2,12)).
# profile(490, choose(3,9)).
# profile(491, choose(1,3)).
# profile(491, choose(2,12)).
# profile(491, choose(3,10)).
# profile(492, choose(1,3)).
# profile(492, choose(2,12)).
# profile(492, choose(3,11)).
# profile(493, choose(1,3)).
# profile(493, choose(2,12)).
# profile(493, choose(3,12)).
# profile(494, choose(1,3)).
# profile(494, choose(2,12)).
# profile(494, choose(3,13)).
# profile(495, choose(1,3)).
# profile(495, choose(2,13)).
# profile(495, choose(3,1)).
# profile(496, choose(1,3)).
# profile(496, choose(2,13)).
# profile(496, choose(3,2)).
# profile(497, choose(1,3)).
# profile(497, choose(2,13)).
# profile(497, choose(3,3)).
# profile(498, choose(1,3)).
# profile(498, choose(2,13)).
# profile(498, choose(3,4)).
# profile(499, choose(1,3)).
# profile(499, choose(2,13)).
# profile(499, choose(3,5)).
# profile(500, choose(1,3)).
# profile(500, choose(2,13)).
# profile(500, choose(3,6)).
# profile(501, choose(1,3)).
# profile(501, choose(2,13)).
# profile(501, choose(3,7)).
# profile(502, choose(1,3)).
# profile(502, choose(2,13)).
# profile(502, choose(3,8)).
# profile(503, choose(1,3)).
# profile(503, choose(2,13)).
# profile(503, choose(3,9)).
# profile(504, choose(1,3)).
# profile(504, choose(2,13)).
# profile(504, choose(3,10)).
# profile(505, choose(1,3)).
# profile(505, choose(2,13)).
# profile(505, choose(3,11)).
# profile(506, choose(1,3)).
# profile(506, choose(2,13)).
# profile(506, choose(3,12)).
# profile(507, choose(1,3)).
# profile(507, choose(2,13)).
# profile(507, choose(3,13)).
# profile(508, choose(1,4)).
# profile(508, choose(2,1)).
# profile(508, choose(3,1)).
# profile(509, choose(1,4)).
# profile(509, choose(2,1)).
# profile(509, choose(3,2)).
# profile(510, choose(1,4)).
# profile(510, choose(2,1)).
# profile(510, choose(3,3)).
# profile(511, choose(1,4)).
# profile(511, choose(2,1)).
# profile(511, choose(3,4)).
# profile(512, choose(1,4)).
# profile(512, choose(2,1)).
# profile(512, choose(3,5)).
# profile(513, choose(1,4)).
# profile(513, choose(2,1)).
# profile(513, choose(3,6)).
# profile(514, choose(1,4)).
# profile(514, choose(2,1)).
# profile(514, choose(3,7)).
# profile(515, choose(1,4)).
# profile(515, choose(2,1)).
# profile(515, choose(3,8)).
# profile(516, choose(1,4)).
# profile(516, choose(2,1)).
# profile(516, choose(3,9)).
# profile(517, choose(1,4)).
# profile(517, choose(2,1)).
# profile(517, choose(3,10)).
# profile(518, choose(1,4)).
# profile(518, choose(2,1)).
# profile(518, choose(3,11)).
# profile(519, choose(1,4)).
# profile(519, choose(2,1)).
# profile(519, choose(3,12)).
# profile(520, choose(1,4)).
# profile(520, choose(2,1)).
# profile(520, choose(3,13)).
# profile(521, choose(1,4)).
# profile(521, choose(2,2)).
# profile(521, choose(3,1)).
# profile(522, choose(1,4)).
# profile(522, choose(2,2)).
# profile(522, choose(3,2)).
# profile(523, choose(1,4)).
# profile(523, choose(2,2)).
# profile(523, choose(3,3)).
# profile(524, choose(1,4)).
# profile(524, choose(2,2)).
# profile(524, choose(3,4)).
# profile(525, choose(1,4)).
# profile(525, choose(2,2)).
# profile(525, choose(3,5)).
# profile(526, choose(1,4)).
# profile(526, choose(2,2)).
# profile(526, choose(3,6)).
# profile(527, choose(1,4)).
# profile(527, choose(2,2)).
# profile(527, choose(3,7)).
# profile(528, choose(1,4)).
# profile(528, choose(2,2)).
# profile(528, choose(3,8)).
# profile(529, choose(1,4)).
# profile(529, choose(2,2)).
# profile(529, choose(3,9)).
# profile(530, choose(1,4)).
# profile(530, choose(2,2)).
# profile(530, choose(3,10)).
# profile(531, choose(1,4)).
# profile(531, choose(2,2)).
# profile(531, choose(3,11)).
# profile(532, choose(1,4)).
# profile(532, choose(2,2)).
# profile(532, choose(3,12)).
# profile(533, choose(1,4)).
# profile(533, choose(2,2)).
# profile(533, choose(3,13)).
# profile(534, choose(1,4)).
# profile(534, choose(2,3)).
# profile(534, choose(3,1)).
# profile(535, choose(1,4)).
# profile(535, choose(2,3)).
# profile(535, choose(3,2)).
# profile(536, choose(1,4)).
# profile(536, choose(2,3)).
# profile(536, choose(3,3)).
# profile(537, choose(1,4)).
# profile(537, choose(2,3)).
# profile(537, choose(3,4)).
# profile(538, choose(1,4)).
# profile(538, choose(2,3)).
# profile(538, choose(3,5)).
# profile(539, choose(1,4)).
# profile(539, choose(2,3)).
# profile(539, choose(3,6)).
# profile(540, choose(1,4)).
# profile(540, choose(2,3)).
# profile(540, choose(3,7)).
# profile(541, choose(1,4)).
# profile(541, choose(2,3)).
# profile(541, choose(3,8)).
# profile(542, choose(1,4)).
# profile(542, choose(2,3)).
# profile(542, choose(3,9)).
# profile(543, choose(1,4)).
# profile(543, choose(2,3)).
# profile(543, choose(3,10)).
# profile(544, choose(1,4)).
# profile(544, choose(2,3)).
# profile(544, choose(3,11)).
# profile(545, choose(1,4)).
# profile(545, choose(2,3)).
# profile(545, choose(3,12)).
# profile(546, choose(1,4)).
# profile(546, choose(2,3)).
# profile(546, choose(3,13)).
# profile(547, choose(1,4)).
# profile(547, choose(2,4)).
# profile(547, choose(3,1)).
# profile(548, choose(1,4)).
# profile(548, choose(2,4)).
# profile(548, choose(3,2)).
# profile(549, choose(1,4)).
# profile(549, choose(2,4)).
# profile(549, choose(3,3)).
# profile(550, choose(1,4)).
# profile(550, choose(2,4)).
# profile(550, choose(3,4)).
# profile(551, choose(1,4)).
# profile(551, choose(2,4)).
# profile(551, choose(3,5)).
# profile(552, choose(1,4)).
# profile(552, choose(2,4)).
# profile(552, choose(3,6)).
# profile(553, choose(1,4)).
# profile(553, choose(2,4)).
# profile(553, choose(3,7)).
# profile(554, choose(1,4)).
# profile(554, choose(2,4)).
# profile(554, choose(3,8)).
# profile(555, choose(1,4)).
# profile(555, choose(2,4)).
# profile(555, choose(3,9)).
# profile(556, choose(1,4)).
# profile(556, choose(2,4)).
# profile(556, choose(3,10)).
# profile(557, choose(1,4)).
# profile(557, choose(2,4)).
# profile(557, choose(3,11)).
# profile(558, choose(1,4)).
# profile(558, choose(2,4)).
# profile(558, choose(3,12)).
# profile(559, choose(1,4)).
# profile(559, choose(2,4)).
# profile(559, choose(3,13)).
# profile(560, choose(1,4)).
# profile(560, choose(2,5)).
# profile(560, choose(3,1)).
# profile(561, choose(1,4)).
# profile(561, choose(2,5)).
# profile(561, choose(3,2)).
# profile(562, choose(1,4)).
# profile(562, choose(2,5)).
# profile(562, choose(3,3)).
# profile(563, choose(1,4)).
# profile(563, choose(2,5)).
# profile(563, choose(3,4)).
# profile(564, choose(1,4)).
# profile(564, choose(2,5)).
# profile(564, choose(3,5)).
# profile(565, choose(1,4)).
# profile(565, choose(2,5)).
# profile(565, choose(3,6)).
# profile(566, choose(1,4)).
# profile(566, choose(2,5)).
# profile(566, choose(3,7)).
# profile(567, choose(1,4)).
# profile(567, choose(2,5)).
# profile(567, choose(3,8)).
# profile(568, choose(1,4)).
# profile(568, choose(2,5)).
# profile(568, choose(3,9)).
# profile(569, choose(1,4)).
# profile(569, choose(2,5)).
# profile(569, choose(3,10)).
# profile(570, choose(1,4)).
# profile(570, choose(2,5)).
# profile(570, choose(3,11)).
# profile(571, choose(1,4)).
# profile(571, choose(2,5)).
# profile(571, choose(3,12)).
# profile(572, choose(1,4)).
# profile(572, choose(2,5)).
# profile(572, choose(3,13)).
# profile(573, choose(1,4)).
# profile(573, choose(2,6)).
# profile(573, choose(3,1)).
# profile(574, choose(1,4)).
# profile(574, choose(2,6)).
# profile(574, choose(3,2)).
# profile(575, choose(1,4)).
# profile(575, choose(2,6)).
# profile(575, choose(3,3)).
# profile(576, choose(1,4)).
# profile(576, choose(2,6)).
# profile(576, choose(3,4)).
# profile(577, choose(1,4)).
# profile(577, choose(2,6)).
# profile(577, choose(3,5)).
# profile(578, choose(1,4)).
# profile(578, choose(2,6)).
# profile(578, choose(3,6)).
# profile(579, choose(1,4)).
# profile(579, choose(2,6)).
# profile(579, choose(3,7)).
# profile(580, choose(1,4)).
# profile(580, choose(2,6)).
# profile(580, choose(3,8)).
# profile(581, choose(1,4)).
# profile(581, choose(2,6)).
# profile(581, choose(3,9)).
# profile(582, choose(1,4)).
# profile(582, choose(2,6)).
# profile(582, choose(3,10)).
# profile(583, choose(1,4)).
# profile(583, choose(2,6)).
# profile(583, choose(3,11)).
# profile(584, choose(1,4)).
# profile(584, choose(2,6)).
# profile(584, choose(3,12)).
# profile(585, choose(1,4)).
# profile(585, choose(2,6)).
# profile(585, choose(3,13)).
# profile(586, choose(1,4)).
# profile(586, choose(2,7)).
# profile(586, choose(3,1)).
# profile(587, choose(1,4)).
# profile(587, choose(2,7)).
# profile(587, choose(3,2)).
# profile(588, choose(1,4)).
# profile(588, choose(2,7)).
# profile(588, choose(3,3)).
# profile(589, choose(1,4)).
# profile(589, choose(2,7)).
# profile(589, choose(3,4)).
# profile(590, choose(1,4)).
# profile(590, choose(2,7)).
# profile(590, choose(3,5)).
# profile(591, choose(1,4)).
# profile(591, choose(2,7)).
# profile(591, choose(3,6)).
# profile(592, choose(1,4)).
# ...
# profile(2011, choose(2,12)).
# profile(2011, choose(3,9)).
# profile(2012, choose(1,12)).
# profile(2012, choose(2,12)).
# profile(2012, choose(3,10)).
# profile(2013, choose(1,12)).
# profile(2013, choose(2,12)).
# profile(2013, choose(3,11)).
# profile(2014, choose(1,12)).
# profile(2014, choose(2,12)).
# profile(2014, choose(3,12)).
# profile(2015, choose(1,12)).
# profile(2015, choose(2,12)).
# profile(2015, choose(3,13)).
# profile(2016, choose(1,12)).
# profile(2016, choose(2,13)).
# profile(2016, choose(3,1)).
# profile(2017, choose(1,12)).
# profile(2017, choose(2,13)).
# profile(2017, choose(3,2)).
# profile(2018, choose(1,12)).
# profile(2018, choose(2,13)).
# profile(2018, choose(3,3)).
# profile(2019, choose(1,12)).
# profile(2019, choose(2,13)).
# profile(2019, choose(3,4)).
# profile(2020, choose(1,12)).
# profile(2020, choose(2,13)).
# profile(2020, choose(3,5)).
# profile(2021, choose(1,12)).
# profile(2021, choose(2,13)).
# profile(2021, choose(3,6)).
# profile(2022, choose(1,12)).
# profile(2022, choose(2,13)).
# profile(2022, choose(3,7)).
# profile(2023, choose(1,12)).
# profile(2023, choose(2,13)).
# profile(2023, choose(3,8)).
# profile(2024, choose(1,12)).
# profile(2024, choose(2,13)).
# profile(2024, choose(3,9)).
# profile(2025, choose(1,12)).
# profile(2025, choose(2,13)).
# profile(2025, choose(3,10)).
# profile(2026, choose(1,12)).
# profile(2026, choose(2,13)).
# profile(2026, choose(3,11)).
# profile(2027, choose(1,12)).
# profile(2027, choose(2,13)).
# profile(2027, choose(3,12)).
# profile(2028, choose(1,12)).
# profile(2028, choose(2,13)).
# profile(2028, choose(3,13)).
# profile(2029, choose(1,13)).
# profile(2029, choose(2,1)).
# profile(2029, choose(3,1)).
# profile(2030, choose(1,13)).
# profile(2030, choose(2,1)).
# profile(2030, choose(3,2)).
# profile(2031, choose(1,13)).
# profile(2031, choose(2,1)).
# profile(2031, choose(3,3)).
# profile(2032, choose(1,13)).
# profile(2032, choose(2,1)).
# profile(2032, choose(3,4)).
# profile(2033, choose(1,13)).
# profile(2033, choose(2,1)).
# profile(2033, choose(3,5)).
# profile(2034, choose(1,13)).
# profile(2034, choose(2,1)).
# profile(2034, choose(3,6)).
# profile(2035, choose(1,13)).
# profile(2035, choose(2,1)).
# profile(2035, choose(3,7)).
# profile(2036, choose(1,13)).
# profile(2036, choose(2,1)).
# profile(2036, choose(3,8)).
# profile(2037, choose(1,13)).
# profile(2037, choose(2,1)).
# profile(2037, choose(3,9)).
# profile(2038, choose(1,13)).
# profile(2038, choose(2,1)).
# profile(2038, choose(3,10)).
# profile(2039, choose(1,13)).
# profile(2039, choose(2,1)).
# profile(2039, choose(3,11)).
# profile(2040, choose(1,13)).
# profile(2040, choose(2,1)).
# profile(2040, choose(3,12)).
# profile(2041, choose(1,13)).
# profile(2041, choose(2,1)).
# profile(2041, choose(3,13)).
# profile(2042, choose(1,13)).
# profile(2042, choose(2,2)).
# profile(2042, choose(3,1)).
# profile(2043, choose(1,13)).
# profile(2043, choose(2,2)).
# profile(2043, choose(3,2)).
# profile(2044, choose(1,13)).
# profile(2044, choose(2,2)).
# profile(2044, choose(3,3)).
# profile(2045, choose(1,13)).
# profile(2045, choose(2,2)).
# profile(2045, choose(3,4)).
# profile(2046, choose(1,13)).
# profile(2046, choose(2,2)).
# profile(2046, choose(3,5)).
# profile(2047, choose(1,13)).
# profile(2047, choose(2,2)).
# profile(2047, choose(3,6)).
# profile(2048, choose(1,13)).
# profile(2048, choose(2,2)).
# profile(2048, choose(3,7)).
# profile(2049, choose(1,13)).
# profile(2049, choose(2,2)).
# profile(2049, choose(3,8)).
# profile(2050, choose(1,13)).
# profile(2050, choose(2,2)).
# profile(2050, choose(3,9)).
# profile(2051, choose(1,13)).
# profile(2051, choose(2,2)).
# profile(2051, choose(3,10)).
# profile(2052, choose(1,13)).
# profile(2052, choose(2,2)).
# profile(2052, choose(3,11)).
# profile(2053, choose(1,13)).
# profile(2053, choose(2,2)).
# profile(2053, choose(3,12)).
# profile(2054, choose(1,13)).
# profile(2054, choose(2,2)).
# profile(2054, choose(3,13)).
# profile(2055, choose(1,13)).
# profile(2055, choose(2,3)).
# profile(2055, choose(3,1)).
# profile(2056, choose(1,13)).
# profile(2056, choose(2,3)).
# profile(2056, choose(3,2)).
# profile(2057, choose(1,13)).
# profile(2057, choose(2,3)).
# profile(2057, choose(3,3)).
# profile(2058, choose(1,13)).
# profile(2058, choose(2,3)).
# profile(2058, choose(3,4)).
# profile(2059, choose(1,13)).
# profile(2059, choose(2,3)).
# profile(2059, choose(3,5)).
# profile(2060, choose(1,13)).
# profile(2060, choose(2,3)).
# profile(2060, choose(3,6)).
# profile(2061, choose(1,13)).
# profile(2061, choose(2,3)).
# profile(2061, choose(3,7)).
# profile(2062, choose(1,13)).
# profile(2062, choose(2,3)).
# profile(2062, choose(3,8)).
# profile(2063, choose(1,13)).
# profile(2063, choose(2,3)).
# profile(2063, choose(3,9)).
# profile(2064, choose(1,13)).
# profile(2064, choose(2,3)).
# profile(2064, choose(3,10)).
# profile(2065, choose(1,13)).
# profile(2065, choose(2,3)).
# profile(2065, choose(3,11)).
# profile(2066, choose(1,13)).
# profile(2066, choose(2,3)).
# profile(2066, choose(3,12)).
# profile(2067, choose(1,13)).
# profile(2067, choose(2,3)).
# profile(2067, choose(3,13)).
# profile(2068, choose(1,13)).
# profile(2068, choose(2,4)).
# profile(2068, choose(3,1)).
# profile(2069, choose(1,13)).
# profile(2069, choose(2,4)).
# profile(2069, choose(3,2)).
# profile(2070, choose(1,13)).
# profile(2070, choose(2,4)).
# profile(2070, choose(3,3)).
# profile(2071, choose(1,13)).
# profile(2071, choose(2,4)).
# profile(2071, choose(3,4)).
# profile(2072, choose(1,13)).
# profile(2072, choose(2,4)).
# profile(2072, choose(3,5)).
# profile(2073, choose(1,13)).
# profile(2073, choose(2,4)).
# profile(2073, choose(3,6)).
# profile(2074, choose(1,13)).
# profile(2074, choose(2,4)).
# profile(2074, choose(3,7)).
# profile(2075, choose(1,13)).
# profile(2075, choose(2,4)).
# profile(2075, choose(3,8)).
# profile(2076, choose(1,13)).
# profile(2076, choose(2,4)).
# profile(2076, choose(3,9)).
# profile(2077, choose(1,13)).
# profile(2077, choose(2,4)).
# profile(2077, choose(3,10)).
# profile(2078, choose(1,13)).
# profile(2078, choose(2,4)).
# profile(2078, choose(3,11)).
# profile(2079, choose(1,13)).
# profile(2079, choose(2,4)).
# profile(2079, choose(3,12)).
# profile(2080, choose(1,13)).
# profile(2080, choose(2,4)).
# profile(2080, choose(3,13)).
# profile(2081, choose(1,13)).
# profile(2081, choose(2,5)).
# profile(2081, choose(3,1)).
# profile(2082, choose(1,13)).
# profile(2082, choose(2,5)).
# profile(2082, choose(3,2)).
# profile(2083, choose(1,13)).
# profile(2083, choose(2,5)).
# profile(2083, choose(3,3)).
# profile(2084, choose(1,13)).
# profile(2084, choose(2,5)).
# profile(2084, choose(3,4)).
# profile(2085, choose(1,13)).
# profile(2085, choose(2,5)).
# profile(2085, choose(3,5)).
# profile(2086, choose(1,13)).
# profile(2086, choose(2,5)).
# profile(2086, choose(3,6)).
# profile(2087, choose(1,13)).
# profile(2087, choose(2,5)).
# profile(2087, choose(3,7)).
# profile(2088, choose(1,13)).
# profile(2088, choose(2,5)).
# profile(2088, choose(3,8)).
# profile(2089, choose(1,13)).
# profile(2089, choose(2,5)).
# profile(2089, choose(3,9)).
# profile(2090, choose(1,13)).
# profile(2090, choose(2,5)).
# profile(2090, choose(3,10)).
# profile(2091, choose(1,13)).
# profile(2091, choose(2,5)).
# profile(2091, choose(3,11)).
# profile(2092, choose(1,13)).
# profile(2092, choose(2,5)).
# profile(2092, choose(3,12)).
# profile(2093, choose(1,13)).
# profile(2093, choose(2,5)).
# profile(2093, choose(3,13)).
# profile(2094, choose(1,13)).
# profile(2094, choose(2,6)).
# profile(2094, choose(3,1)).
# profile(2095, choose(1,13)).
# profile(2095, choose(2,6)).
# profile(2095, choose(3,2)).
# profile(2096, choose(1,13)).
# profile(2096, choose(2,6)).
# profile(2096, choose(3,3)).
# profile(2097, choose(1,13)).
# profile(2097, choose(2,6)).
# profile(2097, choose(3,4)).
# profile(2098, choose(1,13)).
# profile(2098, choose(2,6)).
# profile(2098, choose(3,5)).
# profile(2099, choose(1,13)).
# profile(2099, choose(2,6)).
# profile(2099, choose(3,6)).
# profile(2100, choose(1,13)).
# profile(2100, choose(2,6)).
# profile(2100, choose(3,7)).
# profile(2101, choose(1,13)).
# profile(2101, choose(2,6)).
# profile(2101, choose(3,8)).
# profile(2102, choose(1,13)).
# profile(2102, choose(2,6)).
# profile(2102, choose(3,9)).
# profile(2103, choose(1,13)).
# profile(2103, choose(2,6)).
# profile(2103, choose(3,10)).
# profile(2104, choose(1,13)).
# profile(2104, choose(2,6)).
# profile(2104, choose(3,11)).
# profile(2105, choose(1,13)).
# profile(2105, choose(2,6)).
# profile(2105, choose(3,12)).
# profile(2106, choose(1,13)).
# profile(2106, choose(2,6)).
# profile(2106, choose(3,13)).
# profile(2107, choose(1,13)).
# profile(2107, choose(2,7)).
# profile(2107, choose(3,1)).
# profile(2108, choose(1,13)).
# profile(2108, choose(2,7)).
# profile(2108, choose(3,2)).
# profile(2109, choose(1,13)).
# profile(2109, choose(2,7)).
# profile(2109, choose(3,3)).
# profile(2110, choose(1,13)).
# profile(2110, choose(2,7)).
# profile(2110, choose(3,4)).
# profile(2111, choose(1,13)).
# profile(2111, choose(2,7)).
# profile(2111, choose(3,5)).
# profile(2112, choose(1,13)).
# profile(2112, choose(2,7)).
# profile(2112, choose(3,6)).
# profile(2113, choose(1,13)).
# profile(2113, choose(2,7)).
# profile(2113, choose(3,7)).
# profile(2114, choose(1,13)).
# profile(2114, choose(2,7)).
# profile(2114, choose(3,8)).
# profile(2115, choose(1,13)).
# profile(2115, choose(2,7)).
# profile(2115, choose(3,9)).
# profile(2116, choose(1,13)).
# profile(2116, choose(2,7)).
# profile(2116, choose(3,10)).
# profile(2117, choose(1,13)).
# profile(2117, choose(2,7)).
# profile(2117, choose(3,11)).
# profile(2118, choose(1,13)).
# profile(2118, choose(2,7)).
# profile(2118, choose(3,12)).
# profile(2119, choose(1,13)).
# profile(2119, choose(2,7)).
# profile(2119, choose(3,13)).
# profile(2120, choose(1,13)).
# profile(2120, choose(2,8)).
# profile(2120, choose(3,1)).
# profile(2121, choose(1,13)).
# profile(2121, choose(2,8)).
# profile(2121, choose(3,2)).
# profile(2122, choose(1,13)).
# profile(2122, choose(2,8)).
# profile(2122, choose(3,3)).
# profile(2123, choose(1,13)).
# profile(2123, choose(2,8)).
# profile(2123, choose(3,4)).
# profile(2124, choose(1,13)).
# profile(2124, choose(2,8)).
# profile(2124, choose(3,5)).
# profile(2125, choose(1,13)).
# profile(2125, choose(2,8)).
# profile(2125, choose(3,6)).
# profile(2126, choose(1,13)).
# profile(2126, choose(2,8)).
# profile(2126, choose(3,7)).
# profile(2127, choose(1,13)).
# profile(2127, choose(2,8)).
# profile(2127, choose(3,8)).
# profile(2128, choose(1,13)).
# profile(2128, choose(2,8)).
# profile(2128, choose(3,9)).
# profile(2129, choose(1,13)).
# profile(2129, choose(2,8)).
# profile(2129, choose(3,10)).
# profile(2130, choose(1,13)).
# profile(2130, choose(2,8)).
# profile(2130, choose(3,11)).
# profile(2131, choose(1,13)).
# profile(2131, choose(2,8)).
# profile(2131, choose(3,12)).
# profile(2132, choose(1,13)).
# profile(2132, choose(2,8)).
# profile(2132, choose(3,13)).
# profile(2133, choose(1,13)).
# profile(2133, choose(2,9)).
# profile(2133, choose(3,1)).
# profile(2134, choose(1,13)).
# profile(2134, choose(2,9)).
# profile(2134, choose(3,2)).
# profile(2135, choose(1,13)).
# profile(2135, choose(2,9)).
# profile(2135, choose(3,3)).
# profile(2136, choose(1,13)).
# profile(2136, choose(2,9)).
# profile(2136, choose(3,4)).
# profile(2137, choose(1,13)).
# profile(2137, choose(2,9)).
# profile(2137, choose(3,5)).
# profile(2138, choose(1,13)).
# profile(2138, choose(2,9)).
# profile(2138, choose(3,6)).
# profile(2139, choose(1,13)).
# profile(2139, choose(2,9)).
# profile(2139, choose(3,7)).
# profile(2140, choose(1,13)).
# profile(2140, choose(2,9)).
# profile(2140, choose(3,8)).
# profile(2141, choose(1,13)).
# profile(2141, choose(2,9)).
# profile(2141, choose(3,9)).
# profile(2142, choose(1,13)).
# profile(2142, choose(2,9)).
# profile(2142, choose(3,10)).
# profile(2143, choose(1,13)).
# profile(2143, choose(2,9)).
# profile(2143, choose(3,11)).
# profile(2144, choose(1,13)).
# profile(2144, choose(2,9)).
# profile(2144, choose(3,12)).
# profile(2145, choose(1,13)).
# profile(2145, choose(2,9)).
# profile(2145, choose(3,13)).
# profile(2146, choose(1,13)).
# profile(2146, choose(2,10)).
# profile(2146, choose(3,1)).
# profile(2147, choose(1,13)).
# profile(2147, choose(2,10)).
# profile(2147, choose(3,2)).
# profile(2148, choose(1,13)).
# profile(2148, choose(2,10)).
# profile(2148, choose(3,3)).
# profile(2149, choose(1,13)).
# profile(2149, choose(2,10)).
# profile(2149, choose(3,4)).
# profile(2150, choose(1,13)).
# profile(2150, choose(2,10)).
# profile(2150, choose(3,5)).
# profile(2151, choose(1,13)).
# profile(2151, choose(2,10)).
# profile(2151, choose(3,6)).
# profile(2152, choose(1,13)).
# profile(2152, choose(2,10)).
# profile(2152, choose(3,7)).
# profile(2153, choose(1,13)).
# profile(2153, choose(2,10)).
# profile(2153, choose(3,8)).
# profile(2154, choose(1,13)).
# profile(2154, choose(2,10)).
# profile(2154, choose(3,9)).
# profile(2155, choose(1,13)).
# profile(2155, choose(2,10)).
# profile(2155, choose(3,10)).
# profile(2156, choose(1,13)).
# profile(2156, choose(2,10)).
# profile(2156, choose(3,11)).
# profile(2157, choose(1,13)).
# profile(2157, choose(2,10)).
# profile(2157, choose(3,12)).
# profile(2158, choose(1,13)).
# profile(2158, choose(2,10)).
# profile(2158, choose(3,13)).
# profile(2159, choose(1,13)).
# profile(2159, choose(2,11)).
# profile(2159, choose(3,1)).
# profile(2160, choose(1,13)).
# profile(2160, choose(2,11)).
# profile(2160, choose(3,2)).
# profile(2161, choose(1,13)).
# profile(2161, choose(2,11)).
# profile(2161, choose(3,3)).
# profile(2162, choose(1,13)).
# profile(2162, choose(2,11)).
# profile(2162, choose(3,4)).
# profile(2163, choose(1,13)).
# profile(2163, choose(2,11)).
# profile(2163, choose(3,5)).
# profile(2164, choose(1,13)).
# profile(2164, choose(2,11)).
# profile(2164, choose(3,6)).
# profile(2165, choose(1,13)).
# profile(2165, choose(2,11)).
# profile(2165, choose(3,7)).
# profile(2166, choose(1,13)).
# profile(2166, choose(2,11)).
# profile(2166, choose(3,8)).
# profile(2167, choose(1,13)).
# profile(2167, choose(2,11)).
# profile(2167, choose(3,9)).
# profile(2168, choose(1,13)).
# profile(2168, choose(2,11)).
# profile(2168, choose(3,10)).
# profile(2169, choose(1,13)).
# profile(2169, choose(2,11)).
# profile(2169, choose(3,11)).
# profile(2170, choose(1,13)).
# profile(2170, choose(2,11)).
# profile(2170, choose(3,12)).
# profile(2171, choose(1,13)).
# profile(2171, choose(2,11)).
# profile(2171, choose(3,13)).
# profile(2172, choose(1,13)).
# profile(2172, choose(2,12)).
# profile(2172, choose(3,1)).
# profile(2173, choose(1,13)).
# profile(2173, choose(2,12)).
# profile(2173, choose(3,2)).
# profile(2174, choose(1,13)).
# profile(2174, choose(2,12)).
# profile(2174, choose(3,3)).
# profile(2175, choose(1,13)).
# profile(2175, choose(2,12)).
# profile(2175, choose(3,4)).
# profile(2176, choose(1,13)).
# profile(2176, choose(2,12)).
# profile(2176, choose(3,5)).
# profile(2177, choose(1,13)).
# profile(2177, choose(2,12)).
# profile(2177, choose(3,6)).
# profile(2178, choose(1,13)).
# profile(2178, choose(2,12)).
# profile(2178, choose(3,7)).
# profile(2179, choose(1,13)).
# profile(2179, choose(2,12)).
# profile(2179, choose(3,8)).
# profile(2180, choose(1,13)).
# profile(2180, choose(2,12)).
# profile(2180, choose(3,9)).
# profile(2181, choose(1,13)).
# profile(2181, choose(2,12)).
# profile(2181, choose(3,10)).
# profile(2182, choose(1,13)).
# profile(2182, choose(2,12)).
# profile(2182, choose(3,11)).
# profile(2183, choose(1,13)).
# profile(2183, choose(2,12)).
# profile(2183, choose(3,12)).
# profile(2184, choose(1,13)).
# profile(2184, choose(2,12)).
# profile(2184, choose(3,13)).
# profile(2185, choose(1,13)).
# profile(2185, choose(2,13)).
# profile(2185, choose(3,1)).
# profile(2186, choose(1,13)).
# profile(2186, choose(2,13)).
# profile(2186, choose(3,2)).
# profile(2187, choose(1,13)).
# profile(2187, choose(2,13)).
# profile(2187, choose(3,3)).
# profile(2188, choose(1,13)).
# profile(2188, choose(2,13)).
# profile(2188, choose(3,4)).
# profile(2189, choose(1,13)).
# profile(2189, choose(2,13)).
# profile(2189, choose(3,5)).
# profile(2190, choose(1,13)).
# profile(2190, choose(2,13)).
# profile(2190, choose(3,6)).
# profile(2191, choose(1,13)).
# profile(2191, choose(2,13)).
# profile(2191, choose(3,7)).
# profile(2192, choose(1,13)).
# profile(2192, choose(2,13)).
# profile(2192, choose(3,8)).
# profile(2193, choose(1,13)).
# profile(2193, choose(2,13)).
# profile(2193, choose(3,9)).
# profile(2194, choose(1,13)).
# profile(2194, choose(2,13)).
# profile(2194, choose(3,10)).
# profile(2195, choose(1,13)).
# profile(2195, choose(2,13)).
# profile(2195, choose(3,11)).
# profile(2196, choose(1,13)).
# profile(2196, choose(2,13)).
# profile(2196, choose(3,12)).
# profile(2197, choose(1,13)).
# profile(2197, choose(2,13)).
# profile(2197, choose(3,13)).

# %%
out = find_and_output_solution(graph_asp + prof_asp + find_rule, timeout=600)
print(out)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 out = find_and_output_solution(prof_asp + find_rule, timeout=600)
#       2 print(out)
#
# Cell In[2], line 33, in find_and_output_solution(asp_program, timeout, num_threads)
#      30 #log("..Grounding..")
#      32 control = clingo.Control([f"--parallel-mode={num_threads}"])
# ---> 33 control.add("base", [], asp_program)
#      34 control.ground([("base", [])])
#      36 control.configuration.solve.models = 0
#
# File c:\Users\Farrukh\anaconda3\envs\krr\lib\site-packages\clingo\control.py:307, in Control.add(self, *args, **kwargs)
#     305     self._add1(*args, **kwargs)
#     306 else:
# --> 307     self._add2(*args, **kwargs)
#
# File c:\Users\Farrukh\anaconda3\envs\krr\lib\site-packages\clingo\control.py:318, in Control._add2(self, name, parameters, program)
#     316     c_mem.append(_ffi.new("char[]", param.encode()))
#     317     c_params[i] = c_mem[-1]
# --> 318 _handle_error(
#     319     _lib.clingo_control_add(
#     320         self._rep, name.encode(), c_params, len(parameters), program.encode()
#     321     )
#     322 )
#
# File c:\Users\Farrukh\anaconda3\envs\krr\lib\site-packages\clingo\_internal.py:75, in _handle_error(ret, handler)
#      73 if code == _lib.clingo_error_bad_alloc:
#      74     raise MemoryError(msg)
# ---> 75 raise RuntimeError(msg)
#
# RuntimeError: parsing failed
